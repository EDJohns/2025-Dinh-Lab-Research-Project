# %% [markdown]
# # MAPS
# **MAPS** (**M**achine learning for **A**nalysis of **P**roteomics in **S**patial biology) is a Python package and includes a cell_phenotyping module, which is specifically designed for pathologist-level cell phenotyping from multiplex images of histology tissue through machine learning.

# %% [markdown]
# ## Cell Phenotyping
# The cell_phenotyping module in MAPS provides a machine learning pipeline to train a robust cell classification model on a given dataset and to use a pretrained model to make prediction on new data.

# %% [markdown]
# ### Model Input
# To use cell_phenotyping module, the dataset should be prepared in a CSV format with at least N+1 columns, where N is the number of markers in the given dataset, and the additional column is for cell size. Each row of the CSV file should represent marker expressions for a particular cell along with its size.
#
# To train a new cell phenotyping model, the dataset needs to be split into train and validation CSV files. Both of these files should have an additional column called 'cell_label', which provides the ground truth (class ID) for each cell.

# %%
import pandas as pd
import random
import os
#import utils
import numpy as np
import json
import time

os.chdir('..')

# this file will be resampled while validation set is maintained
maps_train = pd.read_csv('./data/cell_phenotyping/train.csv')

os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 12
#       9 os.chdir('..')
#      11 # this file will be resampled while validation set is maintained
# ---> 12 maps_train = pd.read_csv('./data/cell_phenotyping/train.csv')
#      14 os.getcwd()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/cell_phenotyping/train.csv'

# %%
# read in json, generated from training_resample script
with open('./data/resample/resampled_indices.json', 'r') as f:
    loaded_indices = json.load(f)

# %%
from maps.cell_phenotyping import Trainer
valid_data_path = './data/cell_phenotyping/valid.csv' # validation stays the same

for k,v in loaded_indices.items():
    for k2,v2 in v.items():
        if k != 'sampled_5' and k != 'sampled_2':
    
            temp_out = maps_train.iloc[v2,:]
            temp_out.to_csv('./data/resample/temp/maps_train_subsample.csv', index = False)
            train_data_path = './data/resample/temp/maps_train_subsample.csv'
    
            # make new dir in results:
            results_dir = os.path.join('./data/resample/results/', f'{k}_AND_{k2}')
            os.makedirs(results_dir, exist_ok=True)

            if os.path.exists(os.path.join(results_dir, 'time.txt')):
                print(f"Skipping {k}_AND_{k2}: Already completed.")
                continue
                
            start_time = time.time()
            ##--------------------
            model = Trainer(results_dir=results_dir, num_features=50, num_classes=16, batch_size=128, max_epochs=500, min_epochs=250, patience=100, verbose=0, num_workers=0)
            model.fit(train_data_path, valid_data_path)
            ##---------------------
            end_time = time.time()
            
            elapsed_time = end_time - start_time

            print(f"  -> Training / validation for {k}_AND_{k2} completed in {elapsed_time:.4f} seconds.")
            
            time_filepath = os.path.join(results_dir, 'time.txt')
            with open(time_filepath, 'w') as f:
                f.write(f"{elapsed_time:.4f}")
# Out:
# Skipping sampled_10_AND_resample_1: Already completed.
# Skipping sampled_10_AND_resample_2: Already completed.
# Skipping sampled_10_AND_resample_3: Already completed.
# Skipping sampled_10_AND_resample_4: Already completed.
# Skipping sampled_10_AND_resample_5: Already completed.
# Skipping sampled_15_AND_resample_1: Already completed.
# Skipping sampled_15_AND_resample_2: Already completed.
# Skipping sampled_15_AND_resample_3: Already completed.
# Skipping sampled_15_AND_resample_4: Already completed.
# Skipping sampled_15_AND_resample_5: Already completed.
# Skipping sampled_20_AND_resample_1: Already completed.
# Skipping sampled_20_AND_resample_2: Already completed.
# Skipping sampled_20_AND_resample_3: Already completed.
# Skipping sampled_20_AND_resample_4: Already completed.
# Skipping sampled_20_AND_resample_5: Already completed.
# Skipping sampled_30_AND_resample_1: Already completed.
# Skipping sampled_30_AND_resample_2: Already completed.
# Skipping sampled_30_AND_resample_3: Already completed.
# Skipping sampled_30_AND_resample_4: Already completed.
# Skipping sampled_30_AND_resample_5: Already completed.
# Skipping sampled_50_AND_resample_1: Already completed.
# Skipping sampled_50_AND_resample_2: Already completed.
# Skipping sampled_50_AND_resample_3: Already completed.
# Skipping sampled_50_AND_resample_4: Already completed.
# Skipping sampled_50_AND_resample_5: Already completed.
# Skipping sampled_100_AND_resample_1: Already completed.
# Skipping sampled_100_AND_resample_2: Already completed.
# Skipping sampled_100_AND_resample_3: Already completed.
# Skipping sampled_100_AND_resample_4: Already completed.
# Skipping sampled_100_AND_resample_5: Already completed.
# Skipping sampled_200_AND_resample_1: Already completed.
# Skipping sampled_200_AND_resample_2: Already completed.
# Skipping sampled_200_AND_resample_3: Already completed.
# Skipping sampled_200_AND_resample_4: Already completed.
# Skipping sampled_200_AND_resample_5: Already completed.
# Skipping sampled_500_AND_resample_1: Already completed.
# Skipping sampled_500_AND_resample_2: Already completed.
# Skipping sampled_500_AND_resample_3: Already completed.
# Train Epoch: 0, train_loss: 2.7738, train_acc: 0.0577, train_auc: 0.4820
# Valid Epoch: 0, valid_loss: 2.7748, valid_acc: 0.0670, valid_auc: 0.7284
# --------------------Saving best model--------------------
# Time to process epoch(0): 0.0978 minutes
#
# Train Epoch: 1, train_loss: 2.7544, train_acc: 0.0770, train_auc: 0.5601
# Valid Epoch: 1, valid_loss: 2.5949, valid_acc: 0.0539, valid_auc: 0.7172
# --------------------Saving best model--------------------
# Time to process epoch(1): 0.0977 minutes
#
# Train Epoch: 2, train_loss: 2.3848, train_acc: 0.1704, train_auc: 0.7304
# Valid Epoch: 2, valid_loss: 2.4257, valid_acc: 0.0891, valid_auc: 0.7712
# --------------------Saving best model--------------------
# Time to process epoch(2): 0.0720 minutes
#
# Train Epoch: 3, train_loss: 2.2356, train_acc: 0.2092, train_auc: 0.7758
# Valid Epoch: 3, valid_loss: 2.1880, valid_acc: 0.2794, valid_auc: 0.8054
# --------------------Saving best model--------------------
# Time to process epoch(3): 0.0968 minutes
#
# Train Epoch: 4, train_loss: 2.1608, train_acc: 0.2363, train_auc: 0.8001
# Valid Epoch: 4, valid_loss: 2.1937, valid_acc: 0.2645, valid_auc: 0.8304
# Loss is not decreased in last 1 epochs
# Time to process epoch(4): 0.1796 minutes
#
# Train Epoch: 5, train_loss: 1.9642, train_acc: 0.3170, train_auc: 0.8474
# Valid Epoch: 5, valid_loss: 1.9200, valid_acc: 0.3092, valid_auc: 0.8785
# --------------------Saving best model--------------------
# Time to process epoch(5): 0.0957 minutes
#
# Train Epoch: 6, train_loss: 1.7941, train_acc: 0.3712, train_auc: 0.8745
# Valid Epoch: 6, valid_loss: 1.8528, valid_acc: 0.3784, valid_auc: 0.8855
# --------------------Saving best model--------------------
# Time to process epoch(6): 0.0998 minutes
#
# Train Epoch: 7, train_loss: 1.7002, train_acc: 0.4052, train_auc: 0.8861
# Valid Epoch: 7, valid_loss: 1.8369, valid_acc: 0.3626, valid_auc: 0.9022
# --------------------Saving best model--------------------
# Time to process epoch(7): 0.0988 minutes
#
# Train Epoch: 8, train_loss: 1.5845, train_acc: 0.4430, train_auc: 0.9015
# Valid Epoch: 8, valid_loss: 1.7257, valid_acc: 0.4080, valid_auc: 0.9134
# --------------------Saving best model--------------------
# Time to process epoch(8): 0.0710 minutes
#
# Train Epoch: 9, train_loss: 1.5227, train_acc: 0.4756, train_auc: 0.9113
# Valid Epoch: 9, valid_loss: 1.6374, valid_acc: 0.4393, valid_auc: 0.9263
# --------------------Saving best model--------------------
# Time to process epoch(9): 0.0873 minutes
#
# Train Epoch: 10, train_loss: 1.4124, train_acc: 0.5246, train_auc: 0.9238
# Valid Epoch: 10, valid_loss: 1.6669, valid_acc: 0.4231, valid_auc: 0.9321
# Loss is not decreased in last 1 epochs
# Time to process epoch(10): 0.0620 minutes
#
# Train Epoch: 11, train_loss: 1.3142, train_acc: 0.5645, train_auc: 0.9334
# Valid Epoch: 11, valid_loss: 1.4499, valid_acc: 0.5145, valid_auc: 0.9423
# --------------------Saving best model--------------------
# Time to process epoch(11): 0.0582 minutes
#
# Train Epoch: 12, train_loss: 1.2239, train_acc: 0.5905, train_auc: 0.9398
# Valid Epoch: 12, valid_loss: 1.4138, valid_acc: 0.5049, valid_auc: 0.9458
# --------------------Saving best model--------------------
# Time to process epoch(12): 0.0698 minutes
#
# Train Epoch: 13, train_loss: 1.1630, train_acc: 0.6095, train_auc: 0.9450
# Valid Epoch: 13, valid_loss: 1.3856, valid_acc: 0.5424, valid_auc: 0.9486
# --------------------Saving best model--------------------
# Time to process epoch(13): 0.0643 minutes
#
# Train Epoch: 14, train_loss: 1.1302, train_acc: 0.6253, train_auc: 0.9475
# Valid Epoch: 14, valid_loss: 1.3598, valid_acc: 0.5382, valid_auc: 0.9517
# --------------------Saving best model--------------------
# Time to process epoch(14): 0.0620 minutes
#
# Train Epoch: 15, train_loss: 1.0931, train_acc: 0.6420, train_auc: 0.9515
# Valid Epoch: 15, valid_loss: 1.2428, valid_acc: 0.5794, valid_auc: 0.9550
# --------------------Saving best model--------------------
# Time to process epoch(15): 0.0413 minutes
#
# Train Epoch: 16, train_loss: 1.0165, train_acc: 0.6598, train_auc: 0.9577
# Valid Epoch: 16, valid_loss: 1.2455, valid_acc: 0.5907, valid_auc: 0.9591
# Loss is not decreased in last 1 epochs
# Time to process epoch(16): 0.0440 minutes
#
# Train Epoch: 17, train_loss: 0.9799, train_acc: 0.6826, train_auc: 0.9594
# Valid Epoch: 17, valid_loss: 1.1539, valid_acc: 0.6251, valid_auc: 0.9628
# --------------------Saving best model--------------------
# Time to process epoch(17): 0.0432 minutes
#
# Train Epoch: 18, train_loss: 0.9147, train_acc: 0.7065, train_auc: 0.9651
# Valid Epoch: 18, valid_loss: 1.1582, valid_acc: 0.6075, valid_auc: 0.9640
# Loss is not decreased in last 1 epochs
# Time to process epoch(18): 0.0419 minutes
#
# Train Epoch: 19, train_loss: 0.9150, train_acc: 0.7035, train_auc: 0.9639
# Valid Epoch: 19, valid_loss: 1.1143, valid_acc: 0.6360, valid_auc: 0.9664
# --------------------Saving best model--------------------
# Time to process epoch(19): 0.0415 minutes
#
# Train Epoch: 20, train_loss: 0.8616, train_acc: 0.7155, train_auc: 0.9684
# Valid Epoch: 20, valid_loss: 1.1910, valid_acc: 0.6101, valid_auc: 0.9669
# Loss is not decreased in last 1 epochs
# Time to process epoch(20): 0.0512 minutes
#
# Train Epoch: 21, train_loss: 0.8758, train_acc: 0.7191, train_auc: 0.9679
# Valid Epoch: 21, valid_loss: 1.1233, valid_acc: 0.6350, valid_auc: 0.9677
# Loss is not decreased in last 2 epochs
# Time to process epoch(21): 0.0477 minutes
#
# Train Epoch: 22, train_loss: 0.8272, train_acc: 0.7266, train_auc: 0.9706
# Valid Epoch: 22, valid_loss: 1.0718, valid_acc: 0.6423, valid_auc: 0.9701
# --------------------Saving best model--------------------
# Time to process epoch(22): 0.0465 minutes
#
# Train Epoch: 23, train_loss: 0.8004, train_acc: 0.7345, train_auc: 0.9726
# Valid Epoch: 23, valid_loss: 1.0644, valid_acc: 0.6451, valid_auc: 0.9697
# --------------------Saving best model--------------------
# Time to process epoch(23): 0.0574 minutes
#
# Train Epoch: 24, train_loss: 0.7983, train_acc: 0.7364, train_auc: 0.9720
# Valid Epoch: 24, valid_loss: 1.0559, valid_acc: 0.6622, valid_auc: 0.9708
# --------------------Saving best model--------------------
# Time to process epoch(24): 0.0604 minutes
#
# Train Epoch: 25, train_loss: 0.7958, train_acc: 0.7383, train_auc: 0.9727
# Valid Epoch: 25, valid_loss: 1.0358, valid_acc: 0.6590, valid_auc: 0.9697
# --------------------Saving best model--------------------
# Time to process epoch(25): 0.0637 minutes
#
# Train Epoch: 26, train_loss: 0.8034, train_acc: 0.7461, train_auc: 0.9717
# Valid Epoch: 26, valid_loss: 1.1152, valid_acc: 0.6397, valid_auc: 0.9717
# Loss is not decreased in last 1 epochs
# Time to process epoch(26): 0.0487 minutes
#
# Train Epoch: 27, train_loss: 0.7270, train_acc: 0.7578, train_auc: 0.9772
# Valid Epoch: 27, valid_loss: 1.1375, valid_acc: 0.6367, valid_auc: 0.9715
# Loss is not decreased in last 2 epochs
# Time to process epoch(27): 0.0425 minutes
#
# Train Epoch: 28, train_loss: 0.7194, train_acc: 0.7635, train_auc: 0.9772
# Valid Epoch: 28, valid_loss: 1.0054, valid_acc: 0.6771, valid_auc: 0.9738
# --------------------Saving best model--------------------
# Time to process epoch(28): 0.0420 minutes
#
# Train Epoch: 29, train_loss: 0.7406, train_acc: 0.7579, train_auc: 0.9755
# Valid Epoch: 29, valid_loss: 1.0530, valid_acc: 0.6579, valid_auc: 0.9740
# Loss is not decreased in last 1 epochs
# Time to process epoch(29): 0.0445 minutes
#
# Train Epoch: 30, train_loss: 0.6857, train_acc: 0.7765, train_auc: 0.9792
# Valid Epoch: 30, valid_loss: 1.0597, valid_acc: 0.6621, valid_auc: 0.9735
# Loss is not decreased in last 2 epochs
# Time to process epoch(30): 0.0404 minutes
#
# Train Epoch: 31, train_loss: 0.6970, train_acc: 0.7698, train_auc: 0.9788
# Valid Epoch: 31, valid_loss: 0.9900, valid_acc: 0.6777, valid_auc: 0.9757
# --------------------Saving best model--------------------
# Time to process epoch(31): 0.0424 minutes
#
# Train Epoch: 32, train_loss: 0.6963, train_acc: 0.7693, train_auc: 0.9787
# Valid Epoch: 32, valid_loss: 0.9290, valid_acc: 0.6969, valid_auc: 0.9763
# --------------------Saving best model--------------------
# Time to process epoch(32): 0.0444 minutes
#
# Train Epoch: 33, train_loss: 0.6924, train_acc: 0.7756, train_auc: 0.9786
# Valid Epoch: 33, valid_loss: 0.9131, valid_acc: 0.6978, valid_auc: 0.9773
# --------------------Saving best model--------------------
# Time to process epoch(33): 0.0424 minutes
#
# Train Epoch: 34, train_loss: 0.6535, train_acc: 0.7834, train_auc: 0.9809
# Valid Epoch: 34, valid_loss: 0.9569, valid_acc: 0.6928, valid_auc: 0.9770
# Loss is not decreased in last 1 epochs
# Time to process epoch(34): 0.0423 minutes
#
# Train Epoch: 35, train_loss: 0.6470, train_acc: 0.7867, train_auc: 0.9809
# Valid Epoch: 35, valid_loss: 0.9935, valid_acc: 0.6800, valid_auc: 0.9767
# Loss is not decreased in last 2 epochs
# Time to process epoch(35): 0.0488 minutes
#
# Train Epoch: 36, train_loss: 0.6629, train_acc: 0.7826, train_auc: 0.9807
# Valid Epoch: 36, valid_loss: 0.9623, valid_acc: 0.6930, valid_auc: 0.9779
# Loss is not decreased in last 3 epochs
# Time to process epoch(36): 0.0466 minutes
#
# Train Epoch: 37, train_loss: 0.6397, train_acc: 0.7906, train_auc: 0.9814
# Valid Epoch: 37, valid_loss: 0.8822, valid_acc: 0.7151, valid_auc: 0.9789
# --------------------Saving best model--------------------
# Time to process epoch(37): 0.0343 minutes
#
# Train Epoch: 38, train_loss: 0.6375, train_acc: 0.7892, train_auc: 0.9820
# Valid Epoch: 38, valid_loss: 0.9288, valid_acc: 0.7007, valid_auc: 0.9792
# Loss is not decreased in last 1 epochs
# Time to process epoch(38): 0.0571 minutes
#
# Train Epoch: 39, train_loss: 0.6144, train_acc: 0.7965, train_auc: 0.9832
# Valid Epoch: 39, valid_loss: 0.9144, valid_acc: 0.6997, valid_auc: 0.9783
# Loss is not decreased in last 2 epochs
# Time to process epoch(39): 0.0522 minutes
#
# Train Epoch: 40, train_loss: 0.6018, train_acc: 0.7988, train_auc: 0.9839
# Valid Epoch: 40, valid_loss: 0.8842, valid_acc: 0.7171, valid_auc: 0.9795
# Loss is not decreased in last 3 epochs
# Time to process epoch(40): 0.0479 minutes
#
# Train Epoch: 41, train_loss: 0.5963, train_acc: 0.8019, train_auc: 0.9839
# Valid Epoch: 41, valid_loss: 0.8572, valid_acc: 0.7163, valid_auc: 0.9798
# --------------------Saving best model--------------------
# Time to process epoch(41): 0.0430 minutes
#
# Train Epoch: 42, train_loss: 0.5898, train_acc: 0.8082, train_auc: 0.9844
# Valid Epoch: 42, valid_loss: 0.9864, valid_acc: 0.6821, valid_auc: 0.9799
# Loss is not decreased in last 1 epochs
# Time to process epoch(42): 0.0539 minutes
#
# Train Epoch: 43, train_loss: 0.5779, train_acc: 0.8062, train_auc: 0.9851
# Valid Epoch: 43, valid_loss: 0.9040, valid_acc: 0.7114, valid_auc: 0.9803
# Loss is not decreased in last 2 epochs
# Time to process epoch(43): 0.0528 minutes
#
# Train Epoch: 44, train_loss: 0.5706, train_acc: 0.8090, train_auc: 0.9859
# Valid Epoch: 44, valid_loss: 0.8662, valid_acc: 0.7211, valid_auc: 0.9802
# Loss is not decreased in last 3 epochs
# Time to process epoch(44): 0.0423 minutes
#
# Train Epoch: 45, train_loss: 0.5667, train_acc: 0.8155, train_auc: 0.9857
# Valid Epoch: 45, valid_loss: 1.0250, valid_acc: 0.6837, valid_auc: 0.9782
# Loss is not decreased in last 4 epochs
# Time to process epoch(45): 0.0370 minutes
#
# Train Epoch: 46, train_loss: 0.5836, train_acc: 0.8039, train_auc: 0.9855
# Valid Epoch: 46, valid_loss: 0.8840, valid_acc: 0.7169, valid_auc: 0.9810
# Loss is not decreased in last 5 epochs
# Time to process epoch(46): 0.0456 minutes
#
# Train Epoch: 47, train_loss: 0.5564, train_acc: 0.8157, train_auc: 0.9861
# Valid Epoch: 47, valid_loss: 0.8333, valid_acc: 0.7312, valid_auc: 0.9814
# --------------------Saving best model--------------------
# Time to process epoch(47): 0.0477 minutes
#
# Train Epoch: 48, train_loss: 0.5115, train_acc: 0.8247, train_auc: 0.9880
# Valid Epoch: 48, valid_loss: 0.7960, valid_acc: 0.7390, valid_auc: 0.9816
# --------------------Saving best model--------------------
# Time to process epoch(48): 0.0511 minutes
#
# Train Epoch: 49, train_loss: 0.5439, train_acc: 0.8194, train_auc: 0.9866
# Valid Epoch: 49, valid_loss: 0.8642, valid_acc: 0.7190, valid_auc: 0.9819
# Loss is not decreased in last 1 epochs
# Time to process epoch(49): 0.0522 minutes
#
# Train Epoch: 50, train_loss: 0.5557, train_acc: 0.8145, train_auc: 0.9860
# Valid Epoch: 50, valid_loss: 0.8967, valid_acc: 0.7167, valid_auc: 0.9815
# Loss is not decreased in last 2 epochs
# Time to process epoch(50): 0.0489 minutes
#
# Train Epoch: 51, train_loss: 0.5254, train_acc: 0.8197, train_auc: 0.9880
# Valid Epoch: 51, valid_loss: 0.8548, valid_acc: 0.7261, valid_auc: 0.9821
# Loss is not decreased in last 3 epochs
# Time to process epoch(51): 0.0524 minutes
#
# Train Epoch: 52, train_loss: 0.4976, train_acc: 0.8344, train_auc: 0.9887
# Valid Epoch: 52, valid_loss: 0.9421, valid_acc: 0.7028, valid_auc: 0.9820
# Loss is not decreased in last 4 epochs
# Time to process epoch(52): 0.0499 minutes
#
# Train Epoch: 53, train_loss: 0.4975, train_acc: 0.8305, train_auc: 0.9888
# Valid Epoch: 53, valid_loss: 0.8531, valid_acc: 0.7305, valid_auc: 0.9828
# Loss is not decreased in last 5 epochs
# Time to process epoch(53): 0.0497 minutes
#
# Train Epoch: 54, train_loss: 0.5021, train_acc: 0.8329, train_auc: 0.9886
# Valid Epoch: 54, valid_loss: 0.7801, valid_acc: 0.7502, valid_auc: 0.9830
# --------------------Saving best model--------------------
# Time to process epoch(54): 0.0465 minutes
#
# Train Epoch: 55, train_loss: 0.5029, train_acc: 0.8285, train_auc: 0.9885
# Valid Epoch: 55, valid_loss: 0.7917, valid_acc: 0.7504, valid_auc: 0.9828
# Loss is not decreased in last 1 epochs
# Time to process epoch(55): 0.0537 minutes
#
# Train Epoch: 56, train_loss: 0.4969, train_acc: 0.8310, train_auc: 0.9883
# Valid Epoch: 56, valid_loss: 0.8432, valid_acc: 0.7312, valid_auc: 0.9833
# Loss is not decreased in last 2 epochs
# Time to process epoch(56): 0.0454 minutes
#
# Train Epoch: 57, train_loss: 0.4726, train_acc: 0.8427, train_auc: 0.9898
# Valid Epoch: 57, valid_loss: 0.8984, valid_acc: 0.7179, valid_auc: 0.9830
# Loss is not decreased in last 3 epochs
# Time to process epoch(57): 0.0408 minutes
#
# Train Epoch: 58, train_loss: 0.4715, train_acc: 0.8460, train_auc: 0.9894
# Valid Epoch: 58, valid_loss: 0.8631, valid_acc: 0.7272, valid_auc: 0.9825
# Loss is not decreased in last 4 epochs
# Time to process epoch(58): 0.0435 minutes
#
# Train Epoch: 59, train_loss: 0.4790, train_acc: 0.8363, train_auc: 0.9892
# Valid Epoch: 59, valid_loss: 0.8099, valid_acc: 0.7423, valid_auc: 0.9837
# Loss is not decreased in last 5 epochs
# Time to process epoch(59): 0.0449 minutes
#
# Train Epoch: 60, train_loss: 0.4505, train_acc: 0.8398, train_auc: 0.9904
# Valid Epoch: 60, valid_loss: 0.8103, valid_acc: 0.7451, valid_auc: 0.9834
# Loss is not decreased in last 6 epochs
# Time to process epoch(60): 0.0484 minutes
#
# Train Epoch: 61, train_loss: 0.4565, train_acc: 0.8425, train_auc: 0.9902
# Valid Epoch: 61, valid_loss: 0.8184, valid_acc: 0.7379, valid_auc: 0.9839
# Loss is not decreased in last 7 epochs
# Time to process epoch(61): 0.0430 minutes
#
# Train Epoch: 62, train_loss: 0.4567, train_acc: 0.8456, train_auc: 0.9906
# Valid Epoch: 62, valid_loss: 0.7799, valid_acc: 0.7504, valid_auc: 0.9837
# --------------------Saving best model--------------------
# Time to process epoch(62): 0.0421 minutes
#
# Train Epoch: 63, train_loss: 0.4569, train_acc: 0.8410, train_auc: 0.9905
# Valid Epoch: 63, valid_loss: 0.7647, valid_acc: 0.7556, valid_auc: 0.9836
# --------------------Saving best model--------------------
# Time to process epoch(63): 0.0525 minutes
#
# Train Epoch: 64, train_loss: 0.4519, train_acc: 0.8472, train_auc: 0.9906
# Valid Epoch: 64, valid_loss: 0.7661, valid_acc: 0.7595, valid_auc: 0.9840
# Loss is not decreased in last 1 epochs
# Time to process epoch(64): 0.0433 minutes
#
# Train Epoch: 65, train_loss: 0.4246, train_acc: 0.8524, train_auc: 0.9916
# Valid Epoch: 65, valid_loss: 0.7913, valid_acc: 0.7520, valid_auc: 0.9839
# Loss is not decreased in last 2 epochs
# Time to process epoch(65): 0.0427 minutes
#
# Train Epoch: 66, train_loss: 0.4513, train_acc: 0.8435, train_auc: 0.9906
# Valid Epoch: 66, valid_loss: 0.7431, valid_acc: 0.7617, valid_auc: 0.9841
# --------------------Saving best model--------------------
# Time to process epoch(66): 0.0420 minutes
#
# Train Epoch: 67, train_loss: 0.4254, train_acc: 0.8528, train_auc: 0.9913
# Valid Epoch: 67, valid_loss: 0.8333, valid_acc: 0.7402, valid_auc: 0.9842
# Loss is not decreased in last 1 epochs
# Time to process epoch(67): 0.0614 minutes
#
# Train Epoch: 68, train_loss: 0.4197, train_acc: 0.8558, train_auc: 0.9921
# Valid Epoch: 68, valid_loss: 0.8451, valid_acc: 0.7387, valid_auc: 0.9839
# Loss is not decreased in last 2 epochs
# Time to process epoch(68): 0.0642 minutes
#
# Train Epoch: 69, train_loss: 0.4125, train_acc: 0.8543, train_auc: 0.9922
# Valid Epoch: 69, valid_loss: 0.8223, valid_acc: 0.7451, valid_auc: 0.9843
# Loss is not decreased in last 3 epochs
# Time to process epoch(69): 0.0506 minutes
#
# Train Epoch: 70, train_loss: 0.4215, train_acc: 0.8564, train_auc: 0.9918
# Valid Epoch: 70, valid_loss: 0.7810, valid_acc: 0.7534, valid_auc: 0.9841
# Loss is not decreased in last 4 epochs
# Time to process epoch(70): 0.0516 minutes
#
# Train Epoch: 71, train_loss: 0.4035, train_acc: 0.8587, train_auc: 0.9928
# Valid Epoch: 71, valid_loss: 0.7571, valid_acc: 0.7641, valid_auc: 0.9846
# Loss is not decreased in last 5 epochs
# Time to process epoch(71): 0.0433 minutes
#
# Train Epoch: 72, train_loss: 0.3988, train_acc: 0.8606, train_auc: 0.9922
# Valid Epoch: 72, valid_loss: 0.8163, valid_acc: 0.7418, valid_auc: 0.9846
# Loss is not decreased in last 6 epochs
# Time to process epoch(72): 0.0464 minutes
#
# Train Epoch: 73, train_loss: 0.4062, train_acc: 0.8603, train_auc: 0.9923
# Valid Epoch: 73, valid_loss: 0.7756, valid_acc: 0.7560, valid_auc: 0.9846
# Loss is not decreased in last 7 epochs
# Time to process epoch(73): 0.0592 minutes
#
# Train Epoch: 74, train_loss: 0.3869, train_acc: 0.8659, train_auc: 0.9928
# Valid Epoch: 74, valid_loss: 0.7589, valid_acc: 0.7627, valid_auc: 0.9848
# Loss is not decreased in last 8 epochs
# Time to process epoch(74): 0.0487 minutes
#
# Train Epoch: 75, train_loss: 0.3885, train_acc: 0.8652, train_auc: 0.9929
# Valid Epoch: 75, valid_loss: 0.8499, valid_acc: 0.7365, valid_auc: 0.9850
# Loss is not decreased in last 9 epochs
# Time to process epoch(75): 0.0467 minutes
#
# Train Epoch: 76, train_loss: 0.3818, train_acc: 0.8686, train_auc: 0.9934
# Valid Epoch: 76, valid_loss: 0.8271, valid_acc: 0.7502, valid_auc: 0.9849
# Loss is not decreased in last 10 epochs
# Time to process epoch(76): 0.0473 minutes
#
# Train Epoch: 77, train_loss: 0.3798, train_acc: 0.8637, train_auc: 0.9931
# Valid Epoch: 77, valid_loss: 0.7780, valid_acc: 0.7575, valid_auc: 0.9848
# Loss is not decreased in last 11 epochs
# Time to process epoch(77): 0.0539 minutes
#
# Train Epoch: 78, train_loss: 0.3754, train_acc: 0.8697, train_auc: 0.9931
# Valid Epoch: 78, valid_loss: 0.7894, valid_acc: 0.7586, valid_auc: 0.9846
# Loss is not decreased in last 12 epochs
# Time to process epoch(78): 0.0513 minutes
#
# Train Epoch: 79, train_loss: 0.3858, train_acc: 0.8625, train_auc: 0.9930
# Valid Epoch: 79, valid_loss: 0.8110, valid_acc: 0.7486, valid_auc: 0.9850
# Loss is not decreased in last 13 epochs
# Time to process epoch(79): 0.0465 minutes
#
# Train Epoch: 80, train_loss: 0.3781, train_acc: 0.8635, train_auc: 0.9932
# Valid Epoch: 80, valid_loss: 0.7747, valid_acc: 0.7591, valid_auc: 0.9852
# Loss is not decreased in last 14 epochs
# Time to process epoch(80): 0.0439 minutes
#
# Train Epoch: 81, train_loss: 0.3705, train_acc: 0.8695, train_auc: 0.9936
# Valid Epoch: 81, valid_loss: 0.8129, valid_acc: 0.7519, valid_auc: 0.9848
# Loss is not decreased in last 15 epochs
# Time to process epoch(81): 0.0499 minutes
#
# Train Epoch: 82, train_loss: 0.3761, train_acc: 0.8691, train_auc: 0.9933
# Valid Epoch: 82, valid_loss: 0.8055, valid_acc: 0.7575, valid_auc: 0.9845
# Loss is not decreased in last 16 epochs
# Time to process epoch(82): 0.0449 minutes
#
# Train Epoch: 83, train_loss: 0.3827, train_acc: 0.8635, train_auc: 0.9931
# Valid Epoch: 83, valid_loss: 0.7940, valid_acc: 0.7574, valid_auc: 0.9843
# Loss is not decreased in last 17 epochs
# Time to process epoch(83): 0.0514 minutes
#
# Train Epoch: 84, train_loss: 0.3531, train_acc: 0.8754, train_auc: 0.9943
# Valid Epoch: 84, valid_loss: 0.7789, valid_acc: 0.7647, valid_auc: 0.9854
# Loss is not decreased in last 18 epochs
# Time to process epoch(84): 0.0507 minutes
#
# Train Epoch: 85, train_loss: 0.3708, train_acc: 0.8703, train_auc: 0.9936
# Valid Epoch: 85, valid_loss: 0.7352, valid_acc: 0.7714, valid_auc: 0.9851
# --------------------Saving best model--------------------
# Time to process epoch(85): 0.0474 minutes
#
# Train Epoch: 86, train_loss: 0.3299, train_acc: 0.8822, train_auc: 0.9948
# Valid Epoch: 86, valid_loss: 0.8048, valid_acc: 0.7565, valid_auc: 0.9853
# Loss is not decreased in last 1 epochs
# Time to process epoch(86): 0.0483 minutes
#
# Train Epoch: 87, train_loss: 0.3496, train_acc: 0.8807, train_auc: 0.9938
# Valid Epoch: 87, valid_loss: 0.7545, valid_acc: 0.7664, valid_auc: 0.9851
# Loss is not decreased in last 2 epochs
# Time to process epoch(87): 0.0405 minutes
#
# Train Epoch: 88, train_loss: 0.3517, train_acc: 0.8759, train_auc: 0.9942
# Valid Epoch: 88, valid_loss: 0.7859, valid_acc: 0.7640, valid_auc: 0.9850
# Loss is not decreased in last 3 epochs
# Time to process epoch(88): 0.0413 minutes
#
# Train Epoch: 89, train_loss: 0.3541, train_acc: 0.8736, train_auc: 0.9942
# Valid Epoch: 89, valid_loss: 0.8352, valid_acc: 0.7518, valid_auc: 0.9846
# Loss is not decreased in last 4 epochs
# Time to process epoch(89): 0.0379 minutes
#
# Train Epoch: 90, train_loss: 0.3388, train_acc: 0.8798, train_auc: 0.9944
# Valid Epoch: 90, valid_loss: 0.7574, valid_acc: 0.7700, valid_auc: 0.9852
# Loss is not decreased in last 5 epochs
# Time to process epoch(90): 0.0416 minutes
#
# Train Epoch: 91, train_loss: 0.3393, train_acc: 0.8838, train_auc: 0.9945
# Valid Epoch: 91, valid_loss: 0.8415, valid_acc: 0.7489, valid_auc: 0.9851
# Loss is not decreased in last 6 epochs
# Time to process epoch(91): 0.0400 minutes
#
# Train Epoch: 92, train_loss: 0.3194, train_acc: 0.8884, train_auc: 0.9950
# Valid Epoch: 92, valid_loss: 0.7898, valid_acc: 0.7613, valid_auc: 0.9853
# Loss is not decreased in last 7 epochs
# Time to process epoch(92): 0.0507 minutes
#
# Train Epoch: 93, train_loss: 0.3369, train_acc: 0.8814, train_auc: 0.9944
# Valid Epoch: 93, valid_loss: 0.7566, valid_acc: 0.7698, valid_auc: 0.9855
# Loss is not decreased in last 8 epochs
# Time to process epoch(93): 0.0410 minutes
#
# Train Epoch: 94, train_loss: 0.3314, train_acc: 0.8802, train_auc: 0.9948
# Valid Epoch: 94, valid_loss: 0.8932, valid_acc: 0.7453, valid_auc: 0.9840
# Loss is not decreased in last 9 epochs
# Time to process epoch(94): 0.0442 minutes
#
# Train Epoch: 95, train_loss: 0.3153, train_acc: 0.8877, train_auc: 0.9952
# Valid Epoch: 95, valid_loss: 0.7988, valid_acc: 0.7610, valid_auc: 0.9851
# Loss is not decreased in last 10 epochs
# Time to process epoch(95): 0.0522 minutes
#
# Train Epoch: 96, train_loss: 0.3306, train_acc: 0.8846, train_auc: 0.9947
# Valid Epoch: 96, valid_loss: 0.7664, valid_acc: 0.7690, valid_auc: 0.9851
# Loss is not decreased in last 11 epochs
# Time to process epoch(96): 0.0466 minutes
#
# Train Epoch: 97, train_loss: 0.3329, train_acc: 0.8832, train_auc: 0.9948
# Valid Epoch: 97, valid_loss: 0.7804, valid_acc: 0.7674, valid_auc: 0.9852
# Loss is not decreased in last 12 epochs
# Time to process epoch(97): 0.0509 minutes
#
# Train Epoch: 98, train_loss: 0.3136, train_acc: 0.8872, train_auc: 0.9953
# Valid Epoch: 98, valid_loss: 0.7927, valid_acc: 0.7717, valid_auc: 0.9856
# Loss is not decreased in last 13 epochs
# Time to process epoch(98): 0.0497 minutes
#
# Train Epoch: 99, train_loss: 0.3079, train_acc: 0.8887, train_auc: 0.9954
# Valid Epoch: 99, valid_loss: 0.8854, valid_acc: 0.7471, valid_auc: 0.9848
# Loss is not decreased in last 14 epochs
# Time to process epoch(99): 0.0396 minutes
#
# Train Epoch: 100, train_loss: 0.3119, train_acc: 0.8887, train_auc: 0.9950
# Valid Epoch: 100, valid_loss: 0.9105, valid_acc: 0.7383, valid_auc: 0.9850
# Loss is not decreased in last 15 epochs
# Time to process epoch(100): 0.0393 minutes
#
# Train Epoch: 101, train_loss: 0.3014, train_acc: 0.8953, train_auc: 0.9956
# Valid Epoch: 101, valid_loss: 0.8137, valid_acc: 0.7648, valid_auc: 0.9853
# Loss is not decreased in last 16 epochs
# Time to process epoch(101): 0.0442 minutes
#
# Train Epoch: 102, train_loss: 0.3079, train_acc: 0.8910, train_auc: 0.9953
# Valid Epoch: 102, valid_loss: 0.8362, valid_acc: 0.7513, valid_auc: 0.9856
# Loss is not decreased in last 17 epochs
# Time to process epoch(102): 0.0390 minutes
#
# Train Epoch: 103, train_loss: 0.2922, train_acc: 0.8962, train_auc: 0.9957
# Valid Epoch: 103, valid_loss: 0.8532, valid_acc: 0.7539, valid_auc: 0.9852
# Loss is not decreased in last 18 epochs
# Time to process epoch(103): 0.0386 minutes
#
# Train Epoch: 104, train_loss: 0.2859, train_acc: 0.9008, train_auc: 0.9958
# Valid Epoch: 104, valid_loss: 0.7859, valid_acc: 0.7740, valid_auc: 0.9852
# Loss is not decreased in last 19 epochs
# Time to process epoch(104): 0.0374 minutes
#
# Train Epoch: 105, train_loss: 0.2970, train_acc: 0.8921, train_auc: 0.9958
# Valid Epoch: 105, valid_loss: 0.8007, valid_acc: 0.7686, valid_auc: 0.9853
# Loss is not decreased in last 20 epochs
# Time to process epoch(105): 0.0409 minutes
#
# Train Epoch: 106, train_loss: 0.2871, train_acc: 0.8969, train_auc: 0.9959
# Valid Epoch: 106, valid_loss: 0.7888, valid_acc: 0.7719, valid_auc: 0.9853
# Loss is not decreased in last 21 epochs
# Time to process epoch(106): 0.0552 minutes
#
# Train Epoch: 107, train_loss: 0.3044, train_acc: 0.8885, train_auc: 0.9957
# Valid Epoch: 107, valid_loss: 0.8565, valid_acc: 0.7533, valid_auc: 0.9853
# Loss is not decreased in last 22 epochs
# Time to process epoch(107): 0.0559 minutes
#
# Train Epoch: 108, train_loss: 0.2988, train_acc: 0.8918, train_auc: 0.9956
# Valid Epoch: 108, valid_loss: 0.8515, valid_acc: 0.7624, valid_auc: 0.9852
# Loss is not decreased in last 23 epochs
# Time to process epoch(108): 0.0549 minutes
#
# Train Epoch: 109, train_loss: 0.2879, train_acc: 0.8997, train_auc: 0.9959
# Valid Epoch: 109, valid_loss: 0.8263, valid_acc: 0.7543, valid_auc: 0.9854
# Loss is not decreased in last 24 epochs
# Time to process epoch(109): 0.0422 minutes
#
# Train Epoch: 110, train_loss: 0.2734, train_acc: 0.9044, train_auc: 0.9963
# Valid Epoch: 110, valid_loss: 0.7645, valid_acc: 0.7809, valid_auc: 0.9861
# Loss is not decreased in last 25 epochs
# Time to process epoch(110): 0.0447 minutes
#
# Train Epoch: 111, train_loss: 0.2912, train_acc: 0.8969, train_auc: 0.9958
# Valid Epoch: 111, valid_loss: 0.7708, valid_acc: 0.7751, valid_auc: 0.9857
# Loss is not decreased in last 26 epochs
# Time to process epoch(111): 0.0594 minutes
#
# Train Epoch: 112, train_loss: 0.2818, train_acc: 0.9012, train_auc: 0.9960
# Valid Epoch: 112, valid_loss: 0.8746, valid_acc: 0.7559, valid_auc: 0.9855
# Loss is not decreased in last 27 epochs
# Time to process epoch(112): 0.0501 minutes
#
# Train Epoch: 113, train_loss: 0.3041, train_acc: 0.8919, train_auc: 0.9956
# Valid Epoch: 113, valid_loss: 0.8407, valid_acc: 0.7621, valid_auc: 0.9856
# Loss is not decreased in last 28 epochs
# Time to process epoch(113): 0.0536 minutes
#
# Train Epoch: 114, train_loss: 0.2845, train_acc: 0.8957, train_auc: 0.9960
# Valid Epoch: 114, valid_loss: 0.8777, valid_acc: 0.7522, valid_auc: 0.9851
# Loss is not decreased in last 29 epochs
# Time to process epoch(114): 0.0546 minutes
#
# Train Epoch: 115, train_loss: 0.2702, train_acc: 0.9027, train_auc: 0.9963
# Valid Epoch: 115, valid_loss: 0.8192, valid_acc: 0.7722, valid_auc: 0.9854
# Loss is not decreased in last 30 epochs
# Time to process epoch(115): 0.0400 minutes
#
# Train Epoch: 116, train_loss: 0.2770, train_acc: 0.9013, train_auc: 0.9964
# Valid Epoch: 116, valid_loss: 0.8470, valid_acc: 0.7654, valid_auc: 0.9860
# Loss is not decreased in last 31 epochs
# Time to process epoch(116): 0.0452 minutes
#
# Train Epoch: 117, train_loss: 0.2649, train_acc: 0.9022, train_auc: 0.9966
# Valid Epoch: 117, valid_loss: 0.9095, valid_acc: 0.7548, valid_auc: 0.9852
# Loss is not decreased in last 32 epochs
# Time to process epoch(117): 0.0506 minutes
#
# Train Epoch: 118, train_loss: 0.2672, train_acc: 0.9052, train_auc: 0.9966
# Valid Epoch: 118, valid_loss: 0.8407, valid_acc: 0.7678, valid_auc: 0.9853
# Loss is not decreased in last 33 epochs
# Time to process epoch(118): 0.0522 minutes
#
# Train Epoch: 119, train_loss: 0.2735, train_acc: 0.9037, train_auc: 0.9962
# Valid Epoch: 119, valid_loss: 0.8099, valid_acc: 0.7680, valid_auc: 0.9859
# Loss is not decreased in last 34 epochs
# Time to process epoch(119): 0.0522 minutes
#
# Train Epoch: 120, train_loss: 0.2589, train_acc: 0.9047, train_auc: 0.9966
# Valid Epoch: 120, valid_loss: 0.8126, valid_acc: 0.7680, valid_auc: 0.9852
# Loss is not decreased in last 35 epochs
# Time to process epoch(120): 0.0534 minutes
#
# Train Epoch: 121, train_loss: 0.2588, train_acc: 0.9056, train_auc: 0.9967
# Valid Epoch: 121, valid_loss: 0.8543, valid_acc: 0.7602, valid_auc: 0.9849
# Loss is not decreased in last 36 epochs
# Time to process epoch(121): 0.0449 minutes
#
# Train Epoch: 122, train_loss: 0.2484, train_acc: 0.9086, train_auc: 0.9969
# Valid Epoch: 122, valid_loss: 0.8436, valid_acc: 0.7684, valid_auc: 0.9857
# Loss is not decreased in last 37 epochs
# Time to process epoch(122): 0.0493 minutes
#
# Train Epoch: 123, train_loss: 0.2355, train_acc: 0.9171, train_auc: 0.9972
# Valid Epoch: 123, valid_loss: 0.8411, valid_acc: 0.7680, valid_auc: 0.9854
# Loss is not decreased in last 38 epochs
# Time to process epoch(123): 0.0471 minutes
#
# Train Epoch: 124, train_loss: 0.2457, train_acc: 0.9134, train_auc: 0.9970
# Valid Epoch: 124, valid_loss: 0.9293, valid_acc: 0.7520, valid_auc: 0.9849
# Loss is not decreased in last 39 epochs
# Time to process epoch(124): 0.0561 minutes
#
# Train Epoch: 125, train_loss: 0.2564, train_acc: 0.9090, train_auc: 0.9967
# Valid Epoch: 125, valid_loss: 0.8586, valid_acc: 0.7662, valid_auc: 0.9852
# Loss is not decreased in last 40 epochs
# Time to process epoch(125): 0.0520 minutes
#
# Train Epoch: 126, train_loss: 0.2424, train_acc: 0.9119, train_auc: 0.9971
# Valid Epoch: 126, valid_loss: 0.8698, valid_acc: 0.7651, valid_auc: 0.9852
# Loss is not decreased in last 41 epochs
# Time to process epoch(126): 0.0458 minutes
#
# Train Epoch: 127, train_loss: 0.2420, train_acc: 0.9153, train_auc: 0.9971
# Valid Epoch: 127, valid_loss: 0.8046, valid_acc: 0.7808, valid_auc: 0.9855
# Loss is not decreased in last 42 epochs
# Time to process epoch(127): 0.0559 minutes
#
# Train Epoch: 128, train_loss: 0.2344, train_acc: 0.9134, train_auc: 0.9974
# Valid Epoch: 128, valid_loss: 0.8900, valid_acc: 0.7619, valid_auc: 0.9855
# Loss is not decreased in last 43 epochs
# Time to process epoch(128): 0.0508 minutes
#
# Train Epoch: 129, train_loss: 0.2414, train_acc: 0.9122, train_auc: 0.9971
# Valid Epoch: 129, valid_loss: 0.8925, valid_acc: 0.7624, valid_auc: 0.9857
# Loss is not decreased in last 44 epochs
# Time to process epoch(129): 0.0521 minutes
#
# Train Epoch: 130, train_loss: 0.2337, train_acc: 0.9127, train_auc: 0.9973
# Valid Epoch: 130, valid_loss: 0.9492, valid_acc: 0.7504, valid_auc: 0.9851
# Loss is not decreased in last 45 epochs
# Time to process epoch(130): 0.0484 minutes
#
# Train Epoch: 131, train_loss: 0.2264, train_acc: 0.9165, train_auc: 0.9972
# Valid Epoch: 131, valid_loss: 0.9130, valid_acc: 0.7533, valid_auc: 0.9851
# Loss is not decreased in last 46 epochs
# Time to process epoch(131): 0.0482 minutes
#
# Train Epoch: 132, train_loss: 0.2364, train_acc: 0.9148, train_auc: 0.9971
# Valid Epoch: 132, valid_loss: 0.8164, valid_acc: 0.7784, valid_auc: 0.9856
# Loss is not decreased in last 47 epochs
# Time to process epoch(132): 0.0373 minutes
#
# Train Epoch: 133, train_loss: 0.2223, train_acc: 0.9163, train_auc: 0.9976
# Valid Epoch: 133, valid_loss: 0.8975, valid_acc: 0.7672, valid_auc: 0.9854
# Loss is not decreased in last 48 epochs
# Time to process epoch(133): 0.0420 minutes
#
# Train Epoch: 134, train_loss: 0.2259, train_acc: 0.9165, train_auc: 0.9974
# Valid Epoch: 134, valid_loss: 0.8591, valid_acc: 0.7689, valid_auc: 0.9858
# Loss is not decreased in last 49 epochs
# Time to process epoch(134): 0.0367 minutes
#
# Train Epoch: 135, train_loss: 0.2282, train_acc: 0.9200, train_auc: 0.9974
# Valid Epoch: 135, valid_loss: 0.9435, valid_acc: 0.7529, valid_auc: 0.9852
# Loss is not decreased in last 50 epochs
# Time to process epoch(135): 0.0384 minutes
#
# Train Epoch: 136, train_loss: 0.2343, train_acc: 0.9149, train_auc: 0.9972
# Valid Epoch: 136, valid_loss: 0.8871, valid_acc: 0.7677, valid_auc: 0.9856
# Loss is not decreased in last 51 epochs
# Time to process epoch(136): 0.0407 minutes
#
# Train Epoch: 137, train_loss: 0.2195, train_acc: 0.9197, train_auc: 0.9976
# Valid Epoch: 137, valid_loss: 0.8658, valid_acc: 0.7676, valid_auc: 0.9855
# Loss is not decreased in last 52 epochs
# Time to process epoch(137): 0.0527 minutes
#
# Train Epoch: 138, train_loss: 0.2204, train_acc: 0.9229, train_auc: 0.9974
# Valid Epoch: 138, valid_loss: 0.8919, valid_acc: 0.7609, valid_auc: 0.9854
# Loss is not decreased in last 53 epochs
# Time to process epoch(138): 0.0505 minutes
#
# Train Epoch: 139, train_loss: 0.2279, train_acc: 0.9200, train_auc: 0.9973
# Valid Epoch: 139, valid_loss: 0.9169, valid_acc: 0.7617, valid_auc: 0.9855
# Loss is not decreased in last 54 epochs
# Time to process epoch(139): 0.0584 minutes
#
# Train Epoch: 140, train_loss: 0.2145, train_acc: 0.9236, train_auc: 0.9976
# Valid Epoch: 140, valid_loss: 0.9168, valid_acc: 0.7658, valid_auc: 0.9851
# Loss is not decreased in last 55 epochs
# Time to process epoch(140): 0.0557 minutes
#
# Train Epoch: 141, train_loss: 0.2220, train_acc: 0.9165, train_auc: 0.9977
# Valid Epoch: 141, valid_loss: 0.8661, valid_acc: 0.7688, valid_auc: 0.9852
# Loss is not decreased in last 56 epochs
# Time to process epoch(141): 0.0469 minutes
#
# Train Epoch: 142, train_loss: 0.2190, train_acc: 0.9212, train_auc: 0.9976
# Valid Epoch: 142, valid_loss: 0.8799, valid_acc: 0.7728, valid_auc: 0.9857
# Loss is not decreased in last 57 epochs
# Time to process epoch(142): 0.0565 minutes
#
# Train Epoch: 143, train_loss: 0.2008, train_acc: 0.9269, train_auc: 0.9979
# Valid Epoch: 143, valid_loss: 0.8801, valid_acc: 0.7755, valid_auc: 0.9856
# Loss is not decreased in last 58 epochs
# Time to process epoch(143): 0.0668 minutes
#
# Train Epoch: 144, train_loss: 0.2093, train_acc: 0.9235, train_auc: 0.9978
# Valid Epoch: 144, valid_loss: 0.9181, valid_acc: 0.7654, valid_auc: 0.9857
# Loss is not decreased in last 59 epochs
# Time to process epoch(144): 0.0566 minutes
#
# Train Epoch: 145, train_loss: 0.2203, train_acc: 0.9223, train_auc: 0.9976
# Valid Epoch: 145, valid_loss: 0.8682, valid_acc: 0.7751, valid_auc: 0.9855
# Loss is not decreased in last 60 epochs
# Time to process epoch(145): 0.0554 minutes
#
# Train Epoch: 146, train_loss: 0.2037, train_acc: 0.9268, train_auc: 0.9977
# Valid Epoch: 146, valid_loss: 0.9251, valid_acc: 0.7616, valid_auc: 0.9855
# Loss is not decreased in last 61 epochs
# Time to process epoch(146): 0.0559 minutes
#
# Train Epoch: 147, train_loss: 0.1986, train_acc: 0.9280, train_auc: 0.9981
# Valid Epoch: 147, valid_loss: 0.9127, valid_acc: 0.7689, valid_auc: 0.9854
# Loss is not decreased in last 62 epochs
# Time to process epoch(147): 0.0551 minutes
#
# Train Epoch: 148, train_loss: 0.2019, train_acc: 0.9265, train_auc: 0.9980
# Valid Epoch: 148, valid_loss: 0.9828, valid_acc: 0.7530, valid_auc: 0.9850
# Loss is not decreased in last 63 epochs
# Time to process epoch(148): 0.0614 minutes
#
# Train Epoch: 149, train_loss: 0.2030, train_acc: 0.9278, train_auc: 0.9980
# Valid Epoch: 149, valid_loss: 0.9378, valid_acc: 0.7618, valid_auc: 0.9854
# Loss is not decreased in last 64 epochs
# Time to process epoch(149): 0.0548 minutes
#
# Train Epoch: 150, train_loss: 0.1880, train_acc: 0.9331, train_auc: 0.9980
# Valid Epoch: 150, valid_loss: 1.0422, valid_acc: 0.7461, valid_auc: 0.9849
# Loss is not decreased in last 65 epochs
# Time to process epoch(150): 0.0566 minutes
#
# Train Epoch: 151, train_loss: 0.2068, train_acc: 0.9270, train_auc: 0.9978
# Valid Epoch: 151, valid_loss: 0.9365, valid_acc: 0.7641, valid_auc: 0.9855
# Loss is not decreased in last 66 epochs
# Time to process epoch(151): 0.0551 minutes
#
# Train Epoch: 152, train_loss: 0.1988, train_acc: 0.9260, train_auc: 0.9980
# Valid Epoch: 152, valid_loss: 0.9362, valid_acc: 0.7689, valid_auc: 0.9850
# Loss is not decreased in last 67 epochs
# Time to process epoch(152): 0.0406 minutes
#
# Train Epoch: 153, train_loss: 0.1972, train_acc: 0.9260, train_auc: 0.9981
# Valid Epoch: 153, valid_loss: 0.9163, valid_acc: 0.7727, valid_auc: 0.9855
# Loss is not decreased in last 68 epochs
# ...
# Loss is not decreased in last 104 epochs
# Time to process epoch(197): 0.0427 minutes
#
# Train Epoch: 198, train_loss: 0.1525, train_acc: 0.9441, train_auc: 0.9988
# Valid Epoch: 198, valid_loss: 1.0456, valid_acc: 0.7656, valid_auc: 0.9857
# Loss is not decreased in last 105 epochs
# Time to process epoch(198): 0.0633 minutes
#
# Train Epoch: 199, train_loss: 0.1265, train_acc: 0.9536, train_auc: 0.9992
# Valid Epoch: 199, valid_loss: 0.9447, valid_acc: 0.7847, valid_auc: 0.9861
# Loss is not decreased in last 106 epochs
# Time to process epoch(199): 0.0628 minutes
#
# Train Epoch: 200, train_loss: 0.1364, train_acc: 0.9495, train_auc: 0.9991
# Valid Epoch: 200, valid_loss: 0.9960, valid_acc: 0.7717, valid_auc: 0.9861
# Loss is not decreased in last 107 epochs
# Time to process epoch(200): 0.0532 minutes
#
# Train Epoch: 201, train_loss: 0.1339, train_acc: 0.9520, train_auc: 0.9991
# Valid Epoch: 201, valid_loss: 0.9768, valid_acc: 0.7736, valid_auc: 0.9858
# Loss is not decreased in last 108 epochs
# Time to process epoch(201): 0.0541 minutes
#
# Train Epoch: 202, train_loss: 0.1389, train_acc: 0.9516, train_auc: 0.9990
# Valid Epoch: 202, valid_loss: 1.0226, valid_acc: 0.7677, valid_auc: 0.9860
# Loss is not decreased in last 109 epochs
# Time to process epoch(202): 0.0581 minutes
#
# Train Epoch: 203, train_loss: 0.1612, train_acc: 0.9438, train_auc: 0.9987
# Valid Epoch: 203, valid_loss: 1.0083, valid_acc: 0.7686, valid_auc: 0.9857
# Loss is not decreased in last 110 epochs
# Time to process epoch(203): 0.0539 minutes
#
# Train Epoch: 204, train_loss: 0.1424, train_acc: 0.9491, train_auc: 0.9990
# Valid Epoch: 204, valid_loss: 0.9882, valid_acc: 0.7751, valid_auc: 0.9859
# Loss is not decreased in last 111 epochs
# Time to process epoch(204): 0.0570 minutes
#
# Train Epoch: 205, train_loss: 0.1262, train_acc: 0.9558, train_auc: 0.9992
# Valid Epoch: 205, valid_loss: 1.0612, valid_acc: 0.7694, valid_auc: 0.9859
# Loss is not decreased in last 112 epochs
# Time to process epoch(205): 0.0645 minutes
#
# Train Epoch: 206, train_loss: 0.1423, train_acc: 0.9505, train_auc: 0.9990
# Valid Epoch: 206, valid_loss: 0.9854, valid_acc: 0.7788, valid_auc: 0.9861
# Loss is not decreased in last 113 epochs
# Time to process epoch(206): 0.0553 minutes
#
# Train Epoch: 207, train_loss: 0.1250, train_acc: 0.9538, train_auc: 0.9993
# Valid Epoch: 207, valid_loss: 0.9829, valid_acc: 0.7756, valid_auc: 0.9858
# Loss is not decreased in last 114 epochs
# Time to process epoch(207): 0.0532 minutes
#
# Train Epoch: 208, train_loss: 0.1361, train_acc: 0.9515, train_auc: 0.9990
# Valid Epoch: 208, valid_loss: 1.0750, valid_acc: 0.7655, valid_auc: 0.9855
# Loss is not decreased in last 115 epochs
# Time to process epoch(208): 0.0557 minutes
#
# Train Epoch: 209, train_loss: 0.1293, train_acc: 0.9533, train_auc: 0.9992
# Valid Epoch: 209, valid_loss: 1.0404, valid_acc: 0.7764, valid_auc: 0.9863
# Loss is not decreased in last 116 epochs
# Time to process epoch(209): 0.0465 minutes
#
# Train Epoch: 210, train_loss: 0.1433, train_acc: 0.9490, train_auc: 0.9990
# Valid Epoch: 210, valid_loss: 1.0239, valid_acc: 0.7691, valid_auc: 0.9858
# Loss is not decreased in last 117 epochs
# Time to process epoch(210): 0.0446 minutes
#
# Train Epoch: 211, train_loss: 0.1176, train_acc: 0.9588, train_auc: 0.9993
# Valid Epoch: 211, valid_loss: 1.0713, valid_acc: 0.7683, valid_auc: 0.9859
# Loss is not decreased in last 118 epochs
# Time to process epoch(211): 0.0567 minutes
#
# Train Epoch: 212, train_loss: 0.1260, train_acc: 0.9551, train_auc: 0.9992
# Valid Epoch: 212, valid_loss: 1.0570, valid_acc: 0.7775, valid_auc: 0.9860
# Loss is not decreased in last 119 epochs
# Time to process epoch(212): 0.0553 minutes
#
# Train Epoch: 213, train_loss: 0.1222, train_acc: 0.9579, train_auc: 0.9992
# Valid Epoch: 213, valid_loss: 1.0200, valid_acc: 0.7785, valid_auc: 0.9854
# Loss is not decreased in last 120 epochs
# Time to process epoch(213): 0.0558 minutes
#
# Train Epoch: 214, train_loss: 0.1284, train_acc: 0.9545, train_auc: 0.9992
# Valid Epoch: 214, valid_loss: 1.1468, valid_acc: 0.7594, valid_auc: 0.9855
# Loss is not decreased in last 121 epochs
# Time to process epoch(214): 0.0528 minutes
#
# Train Epoch: 215, train_loss: 0.1207, train_acc: 0.9558, train_auc: 0.9993
# Valid Epoch: 215, valid_loss: 1.0805, valid_acc: 0.7708, valid_auc: 0.9857
# Loss is not decreased in last 122 epochs
# Time to process epoch(215): 0.0503 minutes
#
# Train Epoch: 216, train_loss: 0.1211, train_acc: 0.9555, train_auc: 0.9993
# Valid Epoch: 216, valid_loss: 0.9989, valid_acc: 0.7751, valid_auc: 0.9863
# Loss is not decreased in last 123 epochs
# Time to process epoch(216): 0.0593 minutes
#
# Train Epoch: 217, train_loss: 0.1233, train_acc: 0.9578, train_auc: 0.9992
# Valid Epoch: 217, valid_loss: 0.9794, valid_acc: 0.7821, valid_auc: 0.9861
# Loss is not decreased in last 124 epochs
# Time to process epoch(217): 0.0519 minutes
#
# Train Epoch: 218, train_loss: 0.1193, train_acc: 0.9575, train_auc: 0.9993
# Valid Epoch: 218, valid_loss: 1.0080, valid_acc: 0.7773, valid_auc: 0.9863
# Loss is not decreased in last 125 epochs
# Time to process epoch(218): 0.0534 minutes
#
# Train Epoch: 219, train_loss: 0.1062, train_acc: 0.9613, train_auc: 0.9994
# Valid Epoch: 219, valid_loss: 1.0395, valid_acc: 0.7810, valid_auc: 0.9861
# Loss is not decreased in last 126 epochs
# Time to process epoch(219): 0.0575 minutes
#
# Train Epoch: 220, train_loss: 0.1292, train_acc: 0.9543, train_auc: 0.9992
# Valid Epoch: 220, valid_loss: 1.0543, valid_acc: 0.7703, valid_auc: 0.9862
# Loss is not decreased in last 127 epochs
# Time to process epoch(220): 0.0647 minutes
#
# Train Epoch: 221, train_loss: 0.1054, train_acc: 0.9627, train_auc: 0.9994
# Valid Epoch: 221, valid_loss: 1.0835, valid_acc: 0.7797, valid_auc: 0.9857
# Loss is not decreased in last 128 epochs
# Time to process epoch(221): 0.0624 minutes
#
# Train Epoch: 222, train_loss: 0.1116, train_acc: 0.9588, train_auc: 0.9994
# Valid Epoch: 222, valid_loss: 1.0973, valid_acc: 0.7734, valid_auc: 0.9857
# Loss is not decreased in last 129 epochs
# Time to process epoch(222): 0.0584 minutes
#
# Train Epoch: 223, train_loss: 0.1082, train_acc: 0.9612, train_auc: 0.9994
# Valid Epoch: 223, valid_loss: 1.1054, valid_acc: 0.7759, valid_auc: 0.9863
# Loss is not decreased in last 130 epochs
# Time to process epoch(223): 0.0526 minutes
#
# Train Epoch: 224, train_loss: 0.1261, train_acc: 0.9550, train_auc: 0.9992
# Valid Epoch: 224, valid_loss: 1.1228, valid_acc: 0.7632, valid_auc: 0.9854
# Loss is not decreased in last 131 epochs
# Time to process epoch(224): 0.0409 minutes
#
# Train Epoch: 225, train_loss: 0.1237, train_acc: 0.9558, train_auc: 0.9993
# Valid Epoch: 225, valid_loss: 1.0961, valid_acc: 0.7726, valid_auc: 0.9861
# Loss is not decreased in last 132 epochs
# Time to process epoch(225): 0.0418 minutes
#
# Train Epoch: 226, train_loss: 0.1195, train_acc: 0.9554, train_auc: 0.9993
# Valid Epoch: 226, valid_loss: 1.1982, valid_acc: 0.7561, valid_auc: 0.9859
# Loss is not decreased in last 133 epochs
# Time to process epoch(226): 0.0392 minutes
#
# Train Epoch: 227, train_loss: 0.1054, train_acc: 0.9613, train_auc: 0.9994
# Valid Epoch: 227, valid_loss: 1.1211, valid_acc: 0.7701, valid_auc: 0.9861
# Loss is not decreased in last 134 epochs
# Time to process epoch(227): 0.0381 minutes
#
# Train Epoch: 228, train_loss: 0.1255, train_acc: 0.9536, train_auc: 0.9993
# Valid Epoch: 228, valid_loss: 1.1044, valid_acc: 0.7635, valid_auc: 0.9856
# Loss is not decreased in last 135 epochs
# Time to process epoch(228): 0.0377 minutes
#
# Train Epoch: 229, train_loss: 0.1095, train_acc: 0.9597, train_auc: 0.9994
# Valid Epoch: 229, valid_loss: 1.1401, valid_acc: 0.7641, valid_auc: 0.9857
# Loss is not decreased in last 136 epochs
# Time to process epoch(229): 0.0382 minutes
#
# Train Epoch: 230, train_loss: 0.1120, train_acc: 0.9578, train_auc: 0.9994
# Valid Epoch: 230, valid_loss: 1.2371, valid_acc: 0.7530, valid_auc: 0.9853
# Loss is not decreased in last 137 epochs
# Time to process epoch(230): 0.0403 minutes
#
# Train Epoch: 231, train_loss: 0.1025, train_acc: 0.9635, train_auc: 0.9995
# Valid Epoch: 231, valid_loss: 1.1378, valid_acc: 0.7615, valid_auc: 0.9859
# Loss is not decreased in last 138 epochs
# Time to process epoch(231): 0.0390 minutes
#
# Train Epoch: 232, train_loss: 0.1047, train_acc: 0.9612, train_auc: 0.9994
# Valid Epoch: 232, valid_loss: 1.1302, valid_acc: 0.7726, valid_auc: 0.9858
# Loss is not decreased in last 139 epochs
# Time to process epoch(232): 0.0386 minutes
#
# Train Epoch: 233, train_loss: 0.1013, train_acc: 0.9637, train_auc: 0.9995
# Valid Epoch: 233, valid_loss: 1.1367, valid_acc: 0.7767, valid_auc: 0.9859
# Loss is not decreased in last 140 epochs
# Time to process epoch(233): 0.0391 minutes
#
# Train Epoch: 234, train_loss: 0.0979, train_acc: 0.9638, train_auc: 0.9995
# Valid Epoch: 234, valid_loss: 1.1573, valid_acc: 0.7654, valid_auc: 0.9861
# Loss is not decreased in last 141 epochs
# Time to process epoch(234): 0.0398 minutes
#
# Train Epoch: 235, train_loss: 0.0996, train_acc: 0.9646, train_auc: 0.9995
# Valid Epoch: 235, valid_loss: 1.1636, valid_acc: 0.7744, valid_auc: 0.9850
# Loss is not decreased in last 142 epochs
# Time to process epoch(235): 0.0391 minutes
#
# Train Epoch: 236, train_loss: 0.1082, train_acc: 0.9618, train_auc: 0.9994
# Valid Epoch: 236, valid_loss: 1.1290, valid_acc: 0.7743, valid_auc: 0.9855
# Loss is not decreased in last 143 epochs
# Time to process epoch(236): 0.0393 minutes
#
# Train Epoch: 237, train_loss: 0.0962, train_acc: 0.9661, train_auc: 0.9996
# Valid Epoch: 237, valid_loss: 1.1151, valid_acc: 0.7760, valid_auc: 0.9862
# Loss is not decreased in last 144 epochs
# Time to process epoch(237): 0.0386 minutes
#
# Train Epoch: 238, train_loss: 0.1097, train_acc: 0.9606, train_auc: 0.9994
# Valid Epoch: 238, valid_loss: 1.1112, valid_acc: 0.7750, valid_auc: 0.9857
# Loss is not decreased in last 145 epochs
# Time to process epoch(238): 0.0377 minutes
#
# Train Epoch: 239, train_loss: 0.1244, train_acc: 0.9550, train_auc: 0.9992
# Valid Epoch: 239, valid_loss: 1.1931, valid_acc: 0.7537, valid_auc: 0.9854
# Loss is not decreased in last 146 epochs
# Time to process epoch(239): 0.0381 minutes
#
# Train Epoch: 240, train_loss: 0.1072, train_acc: 0.9618, train_auc: 0.9994
# Valid Epoch: 240, valid_loss: 1.1009, valid_acc: 0.7728, valid_auc: 0.9863
# Loss is not decreased in last 147 epochs
# Time to process epoch(240): 0.0410 minutes
#
# Train Epoch: 241, train_loss: 0.1120, train_acc: 0.9594, train_auc: 0.9994
# Valid Epoch: 241, valid_loss: 1.2109, valid_acc: 0.7614, valid_auc: 0.9852
# Loss is not decreased in last 148 epochs
# Time to process epoch(241): 0.0377 minutes
#
# Train Epoch: 242, train_loss: 0.1031, train_acc: 0.9638, train_auc: 0.9995
# Valid Epoch: 242, valid_loss: 1.2350, valid_acc: 0.7519, valid_auc: 0.9857
# Loss is not decreased in last 149 epochs
# Time to process epoch(242): 0.0370 minutes
#
# Train Epoch: 243, train_loss: 0.1204, train_acc: 0.9561, train_auc: 0.9992
# Valid Epoch: 243, valid_loss: 1.0945, valid_acc: 0.7724, valid_auc: 0.9860
# Loss is not decreased in last 150 epochs
# Time to process epoch(243): 0.0380 minutes
#
# Train Epoch: 244, train_loss: 0.1026, train_acc: 0.9635, train_auc: 0.9995
# Valid Epoch: 244, valid_loss: 1.0900, valid_acc: 0.7791, valid_auc: 0.9861
# Loss is not decreased in last 151 epochs
# Time to process epoch(244): 0.0386 minutes
#
# Train Epoch: 245, train_loss: 0.1042, train_acc: 0.9635, train_auc: 0.9994
# Valid Epoch: 245, valid_loss: 1.1249, valid_acc: 0.7729, valid_auc: 0.9860
# Loss is not decreased in last 152 epochs
# Time to process epoch(245): 0.0402 minutes
#
# Train Epoch: 246, train_loss: 0.0938, train_acc: 0.9655, train_auc: 0.9995
# Valid Epoch: 246, valid_loss: 1.1398, valid_acc: 0.7748, valid_auc: 0.9861
# Loss is not decreased in last 153 epochs
# Time to process epoch(246): 0.0374 minutes
#
# Train Epoch: 247, train_loss: 0.0955, train_acc: 0.9661, train_auc: 0.9995
# Valid Epoch: 247, valid_loss: 1.1900, valid_acc: 0.7701, valid_auc: 0.9857
# Loss is not decreased in last 154 epochs
# Time to process epoch(247): 0.0375 minutes
#
# Train Epoch: 248, train_loss: 0.0943, train_acc: 0.9681, train_auc: 0.9996
# Valid Epoch: 248, valid_loss: 1.1071, valid_acc: 0.7716, valid_auc: 0.9859
# Loss is not decreased in last 155 epochs
# Time to process epoch(248): 0.0384 minutes
#
# Train Epoch: 249, train_loss: 0.0880, train_acc: 0.9691, train_auc: 0.9996
# Valid Epoch: 249, valid_loss: 1.1853, valid_acc: 0.7705, valid_auc: 0.9862
# Loss is not decreased in last 156 epochs
# Time to process epoch(249): 0.0389 minutes
#
# Train Epoch: 250, train_loss: 0.1088, train_acc: 0.9613, train_auc: 0.9994
# Valid Epoch: 250, valid_loss: 1.1743, valid_acc: 0.7707, valid_auc: 0.9858
# Loss is not decreased in last 157 epochs
#   -> Training / validation for sampled_500_AND_resample_5 completed in 668.7423 seconds.

# %% [markdown]
# ### Model Training
#
# The cell_phenotyping module includes a Trainer class, which is designed to handle the model training process. This class comes with various configurable attributes that can be set when instantiating the class, such as the number of classes, number of features, learning rate, batch size, and the number of epochs to train the model. The **fit** method is used to train the model using the training and validation datasets and saves the best model based on the lowest validation loss.

# %%
from maps.cell_phenotyping import Trainer
model = Trainer(results_dir='../results/cell_phenotyping/', num_features=50, num_classes=16, batch_size=128, max_epochs=500, min_epochs=250, patience=100, verbose=0)
model.fit(train_data_path, valid_data_path)

# %% [markdown]
# ### Model Output
# During the training of a new model, the progress is monitored and saved in a CSV file which is stored in a pre-defined results directory. This file contains information about the training progress, such as the loss and accuracy values. Furthermore, the best checkpoint is saved based on the lowest validation loss during the training.

# %%
os.getcwd()
# Out:
# '/Users/jabrand2/Desktop/MAPS'

# %% [markdown]
# ### Model Evaluation
#
# To evaluate the performance of the trained model, the **predict** function is used. This function takes as input a dataset in CSV format, and returns the predicted cell labels along with the probabilities for each class. The output can be further analyzed using various evaluation metrics, such as confusion matrix, precision, recall, F1-score, mean average precision, and precision-recall curve, to determine the performance of the model at the class level. These metrics can help in identifying any potential issues with the model, such as overfitting, and can guide the tuning of hyperparameters for better performance.

# %%
pred_labels, pred_probs = model.predict(valid_data_path)
# Out:
# Batch 225/225

# %% [markdown]
# #### Model Evaluation Prerequisite

# %%
# import pandas as pd
# import utils

# define class names and color palette for visual results 
class_names = ['B', 'CD4 T', 'CD8 T', 'DC', 'Endothelial', 'Epithelial', 'Lymphatic', 'M1', 'M2', 'Mast', 'Monocyte', 'NK', 'Neutrophil', 'Other', 'Treg', 'Tumor']
color_palette =['#bed8d9', '#2bb8b2', '#fed53f', '#f98866', '#fe0000']

# extracting ground truth cell labels for evaluating model performance against ground truth
gt_labels = pd.read_csv(valid_data_path)['cell_label'].to_numpy()

# %% [markdown]
# #### Confusion Matrix
# The confusion matrix provides an overview of the number of correctly and incorrectly classified instances for each class.

# %%
utils.conf_matrix(gt_labels, pred_labels, class_names[:])

# %% [markdown]
# #### Precision, Recall, and F1-score
# Precision measures the proportion of true positives among the predicted positives, while recall measures the proportion of true positives among the actual positives. F1-score is the harmonic mean of precision and recall, providing a balanced measure of the model's performance.

# %% [markdown]
# #### Mean average precision (mAP) and Precision Recall Curves
# Mean average precision (mAP) computes the average precision across all classes, while the precision-recall curve plots the precision-recall trade-off for different classification thresholds.

# %%
utils.average_pr_curve_per_class(gt_labels, pred_labels, pred_probs, class_names)

# %% [markdown]
# ### Model Inference
# The cell_phenotyping module comes with a Predictor class as well that allows for model inference on new datasets lacking a ground truth label column 'cell_label' in the CSV file. The Predictor class requires the path to the pretrained model as input along with number of classes and features in da. It has a predict function that takes a dataset as input and returns predicted labels and probabilities for all classes for each cell in the dataset. This provides a convenient way to leverage the trained model to make predictions on new data without the need for manual cell labeling.

# %%
from maps.cell_phenotyping import Predictor

pretrained_model_checkpoint_path = './models/cell_phenotyping/cHL_CODEX.pt'
model = Predictor(model_checkpoint_path=pretrained_model_checkpoint_path, num_features=50, num_classes=16, batch_size=128)
pred_labels, pred_probs = model.predict(valid_data_path)
# Out:
# Batch 225/225

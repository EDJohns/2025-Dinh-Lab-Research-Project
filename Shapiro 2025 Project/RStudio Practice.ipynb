# %%
#################################################
# EnStats E60 328 #
# Lab 1: RStudio Scavenger Hunt Solutions
#################################################

##############################
## Problem 2
##############################
# helpful R packages
# the ggplot2 package is helpful in making plots.
library(ggplot2)
# the car package is helpful in making Anova tables, 
# something covered in the syllabus
library(readxl)
library(car)


##############################
## Problem 3
##############################
# running the second line printed:
# Error: `path` does not exist: ‘~/NewFolder/Lab1Data.xlsx’

# new second line of code
#Lab1Data <- read_excel("~/Desktop/Lab1Data.xlsx")

# highlighting multiple lines runs the multiple highlighted lines, 
# therefore reading the excel file data into the project.
# the Lab1Data appears in the environment tab on the top right of the window.

# running just the third line of code, which is a variable declaration,
# created the variable in the environment tab.

# running (january) with a clearn environment printed this to the console:
# Error: object 'january' not found

# the (january) line can be run on its own because the january variable is
# not declared and saved in the environment tab.

# running with nothing highlighted runs the entire script,
# therefore executing all the lines in the project.
# All variables appear in the environment tab on the right side and
# all plots appear in the plots section on the bottom right of the window.

##############################
## Problem 4
##############################

# Code Preview:

Lab1Data <- read_excel("C:/Users/evanj/OneDrive/Desktop/Lab1Data.xlsx")
View(Lab1Data)

# File/URL:
# ~/Desktop/Lab1Data.xlsx

# the same Lab1Data is shown in the environment that was created inititally
# when running the code.

##############################
## Problem 5
##############################
# opening the multi-dimensional variable displayed
# $ group : chr [1:20] "january" ...
# $ weight: num [1:20] 20 19.1 19.3 ...
# these are important variables that show the code in "organizing data" how to
# assign the january and august variables

# chr means that group is an array of characters or strings
# num means that weight is an array of numerals/numbers

# subset() creates a subset of data from a larger vector, matrix, etc
# that meets certain conditions. this matches the behavior from running
# the code because two new variables appeared in the environment with
# sections of the Lab1Data based on its group label.

# the pnorm function uses parameters:
# q, mean, sd, lower.tail, and log.p
# when a parameter has a value in the function definition, this it is default
# value is it is not given a new value when the function is called
# the sd arugment is the standard deviation vector used for calculating pnorm

# interesting function: t.test
# this will be helpful when calculating one and two sample t tests this semester
# t.test calculates one and two sample t tests using arguments: 
# x, y, alternative, mu, paired, var.equal, and conf.level
# Example t.test code:
#t.test(extra ~ group, data = sleep)

##############################
## Problem 6
##############################
# running the code saved the function definition to the environment and
# printed the function code to the console
# no, the value of result was not calculated because we were just defining a 
# function to use later. no values were used as arguments yet.

# the value of result was calculated now after running the first line
# in "Using Functions" because we are now calling the function with data.
# result = -19.28

# the first plot doesn't have a title. the third plot has a line of best fit.

# clear the plots by clicking the broom in the top of the plots tab.

# running the second line printed:
# Error: object 'result2' not found
# the syntax error is in the declaration 
# corrected line:
result2 <- plotting(august, january)

# running the third line printed:
# Error in fun_plots(january, january) : 
#   could not find function "fun_plots"
# this line can't be run because you cannot execute functions that aren't
# declared
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6596\315575272.py in <module>
#       9 # helpful R packages
#      10 # the ggplot2 package is helpful in making plots.
# ---> 11 library(ggplot2)
#      12 # the car package is helpful in making Anova tables,
#      13 # something covered in the syllabus
#
# NameError: name 'library' is not defined

# %%
##############################
## Problem 2
##############################
# helpful R packages
# the ggplot2 package is helpful in making plots.
library(ggplot2)
# the car package is helpful in making Anova tables, 
# something covered in the syllabus
library(readxl)
library(car)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6596\1730917535.py in <module>
#       4 # helpful R packages
#       5 # the ggplot2 package is helpful in making plots.
# ----> 6 library(ggplot2)
#       7 # the car package is helpful in making Anova tables,
#       8 # something covered in the syllabus
#
# NameError: name 'library' is not defined

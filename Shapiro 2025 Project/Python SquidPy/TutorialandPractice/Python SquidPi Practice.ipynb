# %% [markdown]
# ## SQUIDPI Practice
#
# This is tutorial show the main functions of SQUIDPI for future reference.

# %%
# Installing Squidpy
# !pip install squidpy
print ('successful output')
# Out:
# Collecting squidpy
#   Downloading squidpy-1.6.5-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: aiohttp>=3.8.1 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from squidpy) (3.10.5)
# Collecting anndata>=0.9 (from squidpy)
#   Downloading anndata-0.11.4-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: cycler>=0.11.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from squidpy) (0.11.0)
# Collecting dask-image>=0.5.0 (from squidpy)
#   Downloading dask_image-2024.5.3-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: dask<=2024.11.2,>=2021.02.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from dask[array]<=2024.11.2,>=2021.02.0->squidpy) (2024.8.2)
# Collecting docrep>=0.3.1 (from squidpy)
#   Downloading docrep-0.3.2.tar.gz (33 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: fsspec>=2021.11.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from squidpy) (2024.6.1)
# Collecting matplotlib-scalebar>=0.8.0 (from squidpy)
#   Downloading matplotlib_scalebar-0.9.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from squidpy) (3.9.2)
# Requirement already satisfied: networkx>=2.6.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from squidpy) (3.3)
# Requirement already satisfied: numba>=0.56.4 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from squidpy) (0.60.0)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from squidpy) (1.26.4)
# Collecting omnipath>=1.0.7 (from squidpy)
#   Downloading omnipath-1.0.10-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: pandas>=2.1.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from squidpy) (2.2.2)
# Requirement already satisfied: pillow>=8.0.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from squidpy) (10.4.0)
# Collecting scanpy>=1.9.3 (from squidpy)
#   Downloading scanpy-1.11.2-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: scikit-image>=0.20 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from squidpy) (0.24.0)
# Requirement already satisfied: scikit-learn>=0.24.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from squidpy) (1.5.1)
# Collecting spatialdata>=0.2.5 (from squidpy)
#   Downloading spatialdata-0.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: statsmodels>=0.12.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from squidpy) (0.14.2)
# Requirement already satisfied: tifffile!=2022.4.22 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from squidpy) (2023.4.12)
# Requirement already satisfied: tqdm>=4.50.2 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from squidpy) (4.66.5)
# Collecting validators>=0.18.2 (from squidpy)
#   Downloading validators-0.35.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting xarray>=2024.10.0 (from squidpy)
#   Downloading xarray-2025.4.0-py3-none-any.whl.metadata (12 kB)
# Collecting zarr<3.0.0,>=2.6.1 (from squidpy)
#   Downloading zarr-2.18.7-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.8.1->squidpy) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.8.1->squidpy) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.8.1->squidpy) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.8.1->squidpy) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.8.1->squidpy) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.8.1->squidpy) (1.11.0)
# Collecting array-api-compat!=1.5,>1.4 (from anndata>=0.9->squidpy)
#   Downloading array_api_compat-1.12.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: h5py>=3.7 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from anndata>=0.9->squidpy) (3.11.0)
# Collecting natsort (from anndata>=0.9->squidpy)
#   Downloading natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting packaging>=24.2 (from anndata>=0.9->squidpy)
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: scipy>1.8 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from anndata>=0.9->squidpy) (1.13.1)
# Requirement already satisfied: click>=8.1 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from dask<=2024.11.2,>=2021.02.0->dask[array]<=2024.11.2,>=2021.02.0->squidpy) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from dask<=2024.11.2,>=2021.02.0->dask[array]<=2024.11.2,>=2021.02.0->squidpy) (3.0.0)
# Requirement already satisfied: partd>=1.4.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from dask<=2024.11.2,>=2021.02.0->dask[array]<=2024.11.2,>=2021.02.0->squidpy) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from dask<=2024.11.2,>=2021.02.0->dask[array]<=2024.11.2,>=2021.02.0->squidpy) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from dask<=2024.11.2,>=2021.02.0->dask[array]<=2024.11.2,>=2021.02.0->squidpy) (0.12.0)
# Collecting pims>=0.4.1 (from dask-image>=0.5.0->squidpy)
#   Downloading pims-0.7.tar.gz (87 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from docrep>=0.3.1->squidpy) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.3->squidpy) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.3->squidpy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.3->squidpy) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.3->squidpy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.3->squidpy) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from numba>=0.56.4->squidpy) (0.43.0)
# Collecting inflect>=4.1.0 (from omnipath>=1.0.7->squidpy)
#   Downloading inflect-7.5.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests>=2.24.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from omnipath>=1.0.7->squidpy) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from omnipath>=1.0.7->squidpy) (4.11.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from omnipath>=1.0.7->squidpy) (2.2.3)
# Requirement already satisfied: wrapt>=1.12.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from omnipath>=1.0.7->squidpy) (1.14.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from pandas>=2.1.0->squidpy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from pandas>=2.1.0->squidpy) (2023.3)
# Requirement already satisfied: joblib in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from scanpy>=1.9.3->squidpy) (1.4.2)
# Collecting legacy-api-wrap>=1.4.1 (from scanpy>=1.9.3->squidpy)
#   Downloading legacy_api_wrap-1.4.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: patsy!=1.0.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from scanpy>=1.9.3->squidpy) (0.5.6)
# Collecting pynndescent>=0.5.13 (from scanpy>=1.9.3->squidpy)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: seaborn>=0.13.2 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from scanpy>=1.9.3->squidpy) (0.13.2)
# Collecting session-info2 (from scanpy>=1.9.3->squidpy)
#   Downloading session_info2-0.1.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting statsmodels>=0.12.0 (from squidpy)
#   Downloading statsmodels-0.14.4-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Collecting umap-learn>=0.5.6 (from scanpy>=1.9.3->squidpy)
#   Downloading umap_learn-0.5.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: imageio>=2.33 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from scikit-image>=0.20->squidpy) (2.33.1)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from scikit-image>=0.20->squidpy) (0.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from scikit-learn>=0.24.0->squidpy) (3.5.0)
# Collecting geopandas>=0.14 (from spatialdata>=0.2.5->squidpy)
#   Downloading geopandas-1.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting multiscale-spatial-image>=2.0.2 (from spatialdata>=0.2.5->squidpy)
#   Downloading multiscale_spatial_image-2.0.2-py3-none-any.whl.metadata (25 kB)
# Collecting ome-zarr>=0.8.4 (from spatialdata>=0.2.5->squidpy)
#   Downloading ome_zarr-0.11.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting pooch (from spatialdata>=0.2.5->squidpy)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pyarrow in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from spatialdata>=0.2.5->squidpy) (16.1.0)
# Requirement already satisfied: rich in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from spatialdata>=0.2.5->squidpy) (13.7.1)
# Requirement already satisfied: setuptools in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from spatialdata>=0.2.5->squidpy) (75.1.0)
# Collecting shapely>=2.0.1 (from spatialdata>=0.2.5->squidpy)
#   Downloading shapely-2.1.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Collecting spatial-image>=1.1.0 (from spatialdata>=0.2.5->squidpy)
#   Downloading spatial_image-1.2.1-py3-none-any.whl.metadata (7.0 kB)
# Collecting xarray-dataclasses>=1.8.0 (from spatialdata>=0.2.5->squidpy)
#   Downloading xarray_dataclasses-1.9.1-py3-none-any.whl.metadata (10 kB)
# Collecting xarray-schema (from spatialdata>=0.2.5->squidpy)
#   Downloading xarray_schema-0.0.3-py3-none-any.whl.metadata (4.3 kB)
# Collecting xarray-spatial>=0.3.5 (from spatialdata>=0.2.5->squidpy)
#   Downloading xarray_spatial-0.4.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: colorama in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from tqdm>=4.50.2->squidpy) (0.4.6)
# Collecting asciitree (from zarr<3.0.0,>=2.6.1->squidpy)
#   Downloading asciitree-0.3.3.tar.gz (4.0 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting fasteners (from zarr<3.0.0,>=2.6.1->squidpy)
#   Downloading fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Collecting numcodecs!=0.14.0,!=0.14.1,<0.16,>=0.10.0 (from zarr<3.0.0,>=2.6.1->squidpy)
#   Downloading numcodecs-0.15.1-cp312-cp312-win_amd64.whl.metadata (3.0 kB)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from dask[array,dataframe]>=2024.4.1->dask-image>=0.5.0->squidpy) (1.1.13)
# Collecting pyogrio>=0.7.2 (from geopandas>=0.14->spatialdata>=0.2.5->squidpy)
#   Downloading pyogrio-0.11.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting pyproj>=3.5.0 (from geopandas>=0.14->spatialdata>=0.2.5->squidpy)
#   Downloading pyproj-3.7.1-cp312-cp312-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: more_itertools>=8.5.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from inflect>=4.1.0->omnipath>=1.0.7->squidpy) (10.3.0)
# Collecting typeguard>=4.0.1 (from inflect>=4.1.0->omnipath>=1.0.7->squidpy)
#   Downloading typeguard-4.4.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting deprecated (from numcodecs!=0.14.0,!=0.14.1,<0.16,>=0.10.0->zarr<3.0.0,>=2.6.1->squidpy)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: locket in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from partd>=1.4.0->dask<=2024.11.2,>=2021.02.0->dask[array]<=2024.11.2,>=2021.02.0->squidpy) (1.0.0)
# Collecting slicerator>=0.9.8 (from pims>=0.4.1->dask-image>=0.5.0->squidpy)
#   Downloading slicerator-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from requests>=2.24.0->omnipath>=1.0.7->squidpy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from requests>=2.24.0->omnipath>=1.0.7->squidpy) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from requests>=2.24.0->omnipath>=1.0.7->squidpy) (2024.8.30)
# Collecting xarray>=2024.10.0 (from squidpy)
#   Downloading xarray-2024.11.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: datashader>=0.15.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from xarray-spatial>=0.3.5->spatialdata>=0.2.5->squidpy) (0.16.3)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from pooch->spatialdata>=0.2.5->squidpy) (3.10.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from rich->spatialdata>=0.2.5->squidpy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from rich->spatialdata>=0.2.5->squidpy) (2.15.1)
# Requirement already satisfied: colorcet in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from datashader>=0.15.0->xarray-spatial>=0.3.5->spatialdata>=0.2.5->squidpy) (3.1.0)
# Requirement already satisfied: multipledispatch in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from datashader>=0.15.0->xarray-spatial>=0.3.5->spatialdata>=0.2.5->squidpy) (0.6.0)
# Requirement already satisfied: param in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from datashader>=0.15.0->xarray-spatial>=0.3.5->spatialdata>=0.2.5->squidpy) (2.1.1)
# Requirement already satisfied: pyct in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from datashader>=0.15.0->xarray-spatial>=0.3.5->spatialdata>=0.2.5->squidpy) (0.5.0)
# Requirement already satisfied: s3fs in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from fsspec[s3]!=2021.07.0,!=2023.9.0,>=0.8->ome-zarr>=0.8.4->spatialdata>=0.2.5->squidpy) (2024.6.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->spatialdata>=0.2.5->squidpy) (0.1.0)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from s3fs->fsspec[s3]!=2021.07.0,!=2023.9.0,>=0.8->ome-zarr>=0.8.4->spatialdata>=0.2.5->squidpy) (2.12.3)
# Requirement already satisfied: botocore<1.34.70,>=1.34.41 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->fsspec[s3]!=2021.07.0,!=2023.9.0,>=0.8->ome-zarr>=0.8.4->spatialdata>=0.2.5->squidpy) (1.34.69)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->fsspec[s3]!=2021.07.0,!=2023.9.0,>=0.8->ome-zarr>=0.8.4->spatialdata>=0.2.5->squidpy) (0.7.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\ejohns\appdata\local\anaconda3\lib\site-packages (from botocore<1.34.70,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs->fsspec[s3]!=2021.07.0,!=2023.9.0,>=0.8->ome-zarr>=0.8.4->spatialdata>=0.2.5->squidpy) (1.0.1)
# Downloading squidpy-1.6.5-py3-none-any.whl (161 kB)
# Downloading anndata-0.11.4-py3-none-any.whl (144 kB)
# Downloading dask_image-2024.5.3-py3-none-any.whl (59 kB)
# Downloading matplotlib_scalebar-0.9.0-py3-none-any.whl (16 kB)
# Downloading omnipath-1.0.10-py3-none-any.whl (108 kB)
# Downloading scanpy-1.11.2-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 29.2 MB/s eta 0:00:00
# Downloading spatialdata-0.4.0-py3-none-any.whl (183 kB)
# Downloading statsmodels-0.14.4-cp312-cp312-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 9.8/9.8 MB 68.3 MB/s eta 0:00:00
# Downloading validators-0.35.0-py3-none-any.whl (44 kB)
# Downloading zarr-2.18.7-py3-none-any.whl (211 kB)
# Downloading array_api_compat-1.12.0-py3-none-any.whl (58 kB)
# Downloading geopandas-1.1.0-py3-none-any.whl (338 kB)
# Downloading inflect-7.5.0-py3-none-any.whl (35 kB)
# Downloading legacy_api_wrap-1.4.1-py3-none-any.whl (10.0 kB)
# Downloading multiscale_spatial_image-2.0.2-py3-none-any.whl (29 kB)
# Downloading numcodecs-0.15.1-cp312-cp312-win_amd64.whl (836 kB)
#    ---------------------------------------- 0.0/836.8 kB ? eta -:--:--
#    --------------------------------------- 836.8/836.8 kB 38.3 MB/s eta 0:00:00
# Downloading ome_zarr-0.11.1-py3-none-any.whl (40 kB)
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
# Downloading shapely-2.1.1-cp312-cp312-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 90.1 MB/s eta 0:00:00
# Downloading spatial_image-1.2.1-py3-none-any.whl (8.7 kB)
# Downloading umap_learn-0.5.7-py3-none-any.whl (88 kB)
# Downloading xarray_dataclasses-1.9.1-py3-none-any.whl (14 kB)
# Downloading xarray-2024.11.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 64.7 MB/s eta 0:00:00
# Downloading xarray_spatial-0.4.0-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 56.6 MB/s eta 0:00:00
# Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Downloading natsort-8.4.0-py3-none-any.whl (38 kB)
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
# Downloading session_info2-0.1.2-py3-none-any.whl (14 kB)
# Downloading xarray_schema-0.0.3-py3-none-any.whl (10 kB)
# Downloading pyogrio-0.11.0-cp312-cp312-win_amd64.whl (19.2 MB)
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#    -------------------------------------- - 18.4/19.2 MB 89.1 MB/s eta 0:00:01
#    ---------------------------------------- 19.2/19.2 MB 71.1 MB/s eta 0:00:00
# Downloading pyproj-3.7.1-cp312-cp312-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 6.3/6.3 MB 64.6 MB/s eta 0:00:00
# Downloading slicerator-1.1.0-py3-none-any.whl (10 kB)
# Downloading typeguard-4.4.2-py3-none-any.whl (35 kB)
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: docrep, pims, asciitree
#   Building wheel for docrep (setup.py): started
#   Building wheel for docrep (setup.py): finished with status 'done'
#   Created wheel for docrep: filename=docrep-0.3.2-py3-none-any.whl size=19903 sha256=ce63e60e0997c8fac1612a0c113295ff55571bdbcc282490c69d3435d6600aec
#   Stored in directory: c:\users\ejohns\appdata\local\pip\cache\wheels\d6\19\ee\0a6a1793d91c449563b49ccab57ce52da3e6fab7614836bd8c
#   Building wheel for pims (setup.py): started
#   Building wheel for pims (setup.py): finished with status 'done'
#   Created wheel for pims: filename=PIMS-0.7-py3-none-any.whl size=85672 sha256=a0ff97e2ec1af23fec304b89ada5cdd07dab8ca31ac10054a18f9d09beeeb827
#   Stored in directory: c:\users\ejohns\appdata\local\pip\cache\wheels\be\9c\72\7cb84823aaa980c2e44064caae0ba869239270fac14f7129aa
#   Building wheel for asciitree (setup.py): started
#   Building wheel for asciitree (setup.py): finished with status 'done'
#   Created wheel for asciitree: filename=asciitree-0.3.3-py3-none-any.whl size=5047 sha256=3408aeb35b11e0b78e785c1b7fb33f09f2adc30ae904998148b0acfaa356b4f1
#   Stored in directory: c:\users\ejohns\appdata\local\pip\cache\wheels\a5\d7\98\f56ae733748cd0fa577172bda0e73e0b1f1793c98e09b9e458
# Successfully built docrep pims asciitree
# Installing collected packages: slicerator, asciitree, validators, typeguard, shapely, session-info2, pyproj, packaging, natsort, legacy-api-wrap, fasteners, docrep, deprecated, array-api-compat, pyogrio, pooch, pims, numcodecs, inflect, zarr, xarray, statsmodels, pynndescent, omnipath, matplotlib-scalebar, geopandas, anndata, xarray-schema, xarray-dataclasses, umap-learn, xarray-spatial, spatial-image, scanpy, dask-image, ome-zarr, multiscale-spatial-image, spatialdata, squidpy
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.1
#     Uninstalling packaging-24.1:
#       Successfully uninstalled packaging-24.1
#   Attempting uninstall: xarray
#     Found existing installation: xarray 2023.6.0
#     Uninstalling xarray-2023.6.0:
#       Successfully uninstalled xarray-2023.6.0
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.14.2
#     Uninstalling statsmodels-0.14.2:
#       Successfully uninstalled statsmodels-0.14.2
# Successfully installed anndata-0.11.4 array-api-compat-1.12.0 asciitree-0.3.3 dask-image-2024.5.3 deprecated-1.2.18 docrep-0.3.2 fasteners-0.19 geopandas-1.1.0 inflect-7.5.0 legacy-api-wrap-1.4.1 matplotlib-scalebar-0.9.0 multiscale-spatial-image-2.0.2 natsort-8.4.0 numcodecs-0.15.1 ome-zarr-0.11.1 omnipath-1.0.10 packaging-25.0 pims-0.7 pooch-1.8.2 pynndescent-0.5.13 pyogrio-0.11.0 pyproj-3.7.1 scanpy-1.11.2 session-info2-0.1.2 shapely-2.1.1 slicerator-1.1.0 spatial-image-1.2.1 spatialdata-0.4.0 squidpy-1.6.5 statsmodels-0.14.4 typeguard-4.4.2 umap-learn-0.5.7 validators-0.35.0 xarray-2024.11.0 xarray-dataclasses-1.9.1 xarray-schema-0.0.3 xarray-spatial-0.4.0 zarr-2.18.7
# successful output
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.37.1 requires packaging<25,>=20, but you have packaging 25.0 which is incompatible.

# %%
environment.yml <https://github.com/scverse/squidpy_notebooks/blob/main/environment.yml>
# Out:
#   Cell In[10], line 1
#     environment.yml <https://github.com/scverse/squidpy_notebooks/blob/main/environment.yml>
#                           ^
# SyntaxError: invalid syntax

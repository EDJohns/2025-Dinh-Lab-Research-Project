# %% [markdown]
# ### Load in RNA Data
#
# Loads CosMX RNA expression data. Will take several minutes

# %%
import scanpy as sc
import squidpy as sq
import pandas as pd
import numpy as np

TMA_Core="A" # Should be A,B,C 

#Load files on laptop
expr= pd.read_csv(fr"C:\Users\evanj\OneDrive\Documents\Shapiro Data Files\Laptop Cutdown RNA Files\RNAexpression_TMA{TMA_Core}_transposed.csv", index_col=0)
#expr=expr_orig.transpose()
metadata = pd.read_csv(fr"C:\Users\evanj\OneDrive\Documents\Shapiro Data Files\Laptop Cutdown RNA Files\RNA_TMA{TMA_Core}_meta_transposed.csv", index_col=0)
umap = pd.read_csv(fr"C:\Users\evanj\OneDrive\Documents\Shapiro Data Files\Laptop Cutdown RNA Files\RNA_TMA{TMA_Core}_umap_transposed.csv", index_col=0)

# Extra - MetaData File
extra_metadata=pd.read_csv(fr"C:\Users\evanj\OneDrive\Documents\Shapiro Data Files\Laptop Cutdown RNA Files\Run_TMA{TMA_Core}_metadata_file.csv", index_col=0)

# Create AnnData object
adata_rna = sc.AnnData(X=expr.values)

# Assign metadata
adata_rna.obs = metadata
adata_rna.var_names = expr.columns
adata_rna.obs_names = expr.index

# Add spatial coordinates and UMAP to .obsm
adata_rna.obsm["spatial"] = metadata[['x_pixel', 'y_pixel']].values  # adjust if needed
# x_pixel, y_pixel, x_norm	y_norm	x_micron	y_micron x_cent	y_cent

adata_rna.obsm["X_umap"] = umap.values
# Out:
# C:\Users\evanj\anaconda3\Lib\site-packages\paramiko\pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# C:\Users\evanj\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.Blowfish and will be removed from this module in 45.0.0.
#   "class": algorithms.Blowfish,
# C:\Users\evanj\anaconda3\Lib\site-packages\paramiko\transport.py:243: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,
# C:\Users\evanj\anaconda3\Lib\site-packages\anndata\utils.py:434: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Load in Ligand and Receptor pairs

# %%
def check_expression(ligand, receptor_list, expr):
    """
    Case-insensitive check.
    Also returns the ligand and receptor names
    in the correct case as stored in expr.columns.
    """

    # Mapping: lowercase → original column name
    expr_map = {col.lower(): col for col in expr.columns}

    # Check ligand
    ligand_lower = ligand.lower()
    ligand_ok = ligand_lower in expr_map
    ligand_corrected = expr_map.get(ligand_lower, None)

    # Check receptors & return corrected names
    receptors_ok = True
    corrected_receptors = []

    for g in receptor_list:
        g_lower = g.lower()
        if g_lower in expr_map:
            corrected_receptors.append(expr_map[g_lower])
        else:
            receptors_ok = False
            corrected_receptors.append(None)  # or keep original

    return ligand_ok, receptors_ok, ligand_corrected, corrected_receptors


# Load files on laptop
LR_pairs = pd.read_csv(fr"C:\Users\evanj\Documents\Din Lab Data Files\cellchat_LR_pairs.csv", index_col=0)

# Convert ligand + receptor columns to NumPy array
lr_array = LR_pairs[["ligand", "receptor"]].to_numpy()

for i in range(100):
    ligand = lr_array[i, 0]
    receptor = lr_array[i, 1]

    # Convert receptor string to list
    receptor_list = receptor.split("_")

    # Check if they exist in expr.columns
    ligand_ok, receptors_ok, ligand_corrected, corrected_receptors = check_expression(ligand, receptor_list, expr)

    print(f"Ligand: {ligand}, OK: {ligand_ok}")
    print(f"Receptors: {ligand_corrected}, OK: {corrected_receptors}")
    print(f"Receptors: {ligand}, OK: {receptor_list}")
    print("----------")
# Out:
# Ligand: TGFB1, OK: True
# Receptors: TGFB1, OK: ['TGFBR1', None]
# Receptors: TGFB1, OK: ['TGFbR1', 'R2']
# ----------
# Ligand: TGFB2, OK: True
# Receptors: TGFB2, OK: ['TGFBR1', None]
# Receptors: TGFB2, OK: ['TGFbR1', 'R2']
# ----------
# Ligand: TGFB3, OK: True
# Receptors: TGFB3, OK: ['TGFBR1', None]
# Receptors: TGFB3, OK: ['TGFbR1', 'R2']
# ----------
# Ligand: TGFB1, OK: True
# Receptors: TGFB1, OK: ['ACVR1B', 'TGFBR2']
# Receptors: TGFB1, OK: ['ACVR1B', 'TGFbR2']
# ----------
# Ligand: TGFB1, OK: True
# Receptors: TGFB1, OK: [None, 'TGFBR2']
# Receptors: TGFB1, OK: ['ACVR1C', 'TGFbR2']
# ----------
# Ligand: TGFB2, OK: True
# Receptors: TGFB2, OK: ['ACVR1B', 'TGFBR2']
# Receptors: TGFB2, OK: ['ACVR1B', 'TGFbR2']
# ----------
# Ligand: TGFB2, OK: True
# Receptors: TGFB2, OK: [None, 'TGFBR2']
# Receptors: TGFB2, OK: ['ACVR1C', 'TGFbR2']
# ----------
# Ligand: TGFB3, OK: True
# Receptors: TGFB3, OK: ['ACVR1B', 'TGFBR2']
# Receptors: TGFB3, OK: ['ACVR1B', 'TGFbR2']
# ----------
# Ligand: TGFB3, OK: True
# Receptors: TGFB3, OK: [None, 'TGFBR2']
# Receptors: TGFB3, OK: ['ACVR1C', 'TGFbR2']
# ----------
# Ligand: TGFB1, OK: True
# Receptors: TGFB1, OK: ['ACVR1', None]
# Receptors: TGFB1, OK: ['ACVR1', 'TGFbR']
# ----------
# Ligand: TGFB2, OK: True
# Receptors: TGFB2, OK: ['ACVR1', None]
# Receptors: TGFB2, OK: ['ACVR1', 'TGFbR']
# ----------
# Ligand: TGFB3, OK: True
# Receptors: TGFB3, OK: ['ACVR1', None]
# Receptors: TGFB3, OK: ['ACVR1', 'TGFbR']
# ----------
# Ligand: BMP2, OK: True
# Receptors: BMP2, OK: ['BMPR1A', 'ACVR2A']
# Receptors: BMP2, OK: ['BMPR1A', 'ACVR2A']
# ----------
# Ligand: BMP2, OK: True
# Receptors: BMP2, OK: ['BMPR1A', None]
# Receptors: BMP2, OK: ['BMPR1A', 'ACVR2B']
# ----------
# Ligand: BMP2, OK: True
# Receptors: BMP2, OK: ['BMPR1A', 'BMPR2']
# Receptors: BMP2, OK: ['BMPR1A', 'BMPR2']
# ----------
# Ligand: BMP2, OK: True
# Receptors: BMP2, OK: [None, 'ACVR2A']
# Receptors: BMP2, OK: ['BMPR1B', 'ACVR2A']
# ----------
# Ligand: BMP2, OK: True
# Receptors: BMP2, OK: [None, None]
# Receptors: BMP2, OK: ['BMPR1B', 'ACVR2B']
# ----------
# Ligand: BMP2, OK: True
# Receptors: BMP2, OK: [None, 'BMPR2']
# Receptors: BMP2, OK: ['BMPR1B', 'BMPR2']
# ----------
# Ligand: BMP4, OK: True
# Receptors: BMP4, OK: ['BMPR1A', 'ACVR2A']
# Receptors: BMP4, OK: ['BMPR1A', 'ACVR2A']
# ----------
# Ligand: BMP4, OK: True
# Receptors: BMP4, OK: ['BMPR1A', None]
# Receptors: BMP4, OK: ['BMPR1A', 'ACVR2B']
# ----------
# Ligand: BMP4, OK: True
# Receptors: BMP4, OK: ['BMPR1A', 'BMPR2']
# Receptors: BMP4, OK: ['BMPR1A', 'BMPR2']
# ----------
# Ligand: BMP4, OK: True
# Receptors: BMP4, OK: [None, 'ACVR2A']
# Receptors: BMP4, OK: ['BMPR1B', 'ACVR2A']
# ----------
# Ligand: BMP4, OK: True
# Receptors: BMP4, OK: [None, None]
# Receptors: BMP4, OK: ['BMPR1B', 'ACVR2B']
# ----------
# Ligand: BMP4, OK: True
# Receptors: BMP4, OK: [None, 'BMPR2']
# Receptors: BMP4, OK: ['BMPR1B', 'BMPR2']
# ----------
# Ligand: GDF5, OK: False
# Receptors: None, OK: ['BMPR1A', 'ACVR2A']
# Receptors: GDF5, OK: ['BMPR1A', 'ACVR2A']
# ----------
# Ligand: GDF5, OK: False
# Receptors: None, OK: ['BMPR1A', None]
# Receptors: GDF5, OK: ['BMPR1A', 'ACVR2B']
# ----------
# Ligand: GDF5, OK: False
# Receptors: None, OK: ['BMPR1A', 'BMPR2']
# Receptors: GDF5, OK: ['BMPR1A', 'BMPR2']
# ----------
# Ligand: GDF5, OK: False
# Receptors: None, OK: [None, 'ACVR2A']
# Receptors: GDF5, OK: ['BMPR1B', 'ACVR2A']
# ----------
# Ligand: GDF5, OK: False
# Receptors: None, OK: [None, None]
# Receptors: GDF5, OK: ['BMPR1B', 'ACVR2B']
# ----------
# Ligand: GDF5, OK: False
# Receptors: None, OK: [None, 'BMPR2']
# Receptors: GDF5, OK: ['BMPR1B', 'BMPR2']
# ----------
# Ligand: GDF6, OK: True
# Receptors: GDF6, OK: ['BMPR1A', 'ACVR2A']
# Receptors: GDF6, OK: ['BMPR1A', 'ACVR2A']
# ----------
# Ligand: GDF6, OK: True
# Receptors: GDF6, OK: ['BMPR1A', None]
# Receptors: GDF6, OK: ['BMPR1A', 'ACVR2B']
# ----------
# Ligand: GDF6, OK: True
# Receptors: GDF6, OK: ['BMPR1A', 'BMPR2']
# Receptors: GDF6, OK: ['BMPR1A', 'BMPR2']
# ----------
# Ligand: GDF6, OK: True
# Receptors: GDF6, OK: [None, 'ACVR2A']
# Receptors: GDF6, OK: ['BMPR1B', 'ACVR2A']
# ----------
# Ligand: GDF6, OK: True
# Receptors: GDF6, OK: [None, None]
# Receptors: GDF6, OK: ['BMPR1B', 'ACVR2B']
# ----------
# Ligand: GDF6, OK: True
# Receptors: GDF6, OK: [None, 'BMPR2']
# Receptors: GDF6, OK: ['BMPR1B', 'BMPR2']
# ----------
# Ligand: GDF7, OK: False
# Receptors: None, OK: ['BMPR1A', 'ACVR2A']
# Receptors: GDF7, OK: ['BMPR1A', 'ACVR2A']
# ----------
# Ligand: GDF7, OK: False
# Receptors: None, OK: ['BMPR1A', None]
# Receptors: GDF7, OK: ['BMPR1A', 'ACVR2B']
# ----------
# Ligand: GDF7, OK: False
# Receptors: None, OK: ['BMPR1A', 'BMPR2']
# Receptors: GDF7, OK: ['BMPR1A', 'BMPR2']
# ----------
# Ligand: GDF7, OK: False
# Receptors: None, OK: [None, 'ACVR2A']
# Receptors: GDF7, OK: ['BMPR1B', 'ACVR2A']
# ----------
# Ligand: GDF7, OK: False
# Receptors: None, OK: [None, None]
# Receptors: GDF7, OK: ['BMPR1B', 'ACVR2B']
# ----------
# Ligand: GDF7, OK: False
# Receptors: None, OK: [None, 'BMPR2']
# Receptors: GDF7, OK: ['BMPR1B', 'BMPR2']
# ----------
# Ligand: BMP15, OK: False
# Receptors: None, OK: [None, 'BMPR2']
# Receptors: BMP15, OK: ['BMPR1B', 'BMPR2']
# ----------
# Ligand: BMP5, OK: True
# Receptors: BMP5, OK: ['ACVR1', 'ACVR2A']
# Receptors: BMP5, OK: ['ACVR1', 'ACVR2A']
# ----------
# Ligand: BMP5, OK: True
# Receptors: BMP5, OK: ['ACVR1', None]
# Receptors: BMP5, OK: ['ACVR1', 'ACVR2B']
# ----------
# Ligand: BMP5, OK: True
# Receptors: BMP5, OK: ['ACVR1', 'BMPR2']
# Receptors: BMP5, OK: ['ACVR1', 'BMPR2']
# ----------
# Ligand: BMP5, OK: True
# Receptors: BMP5, OK: ['BMPR1A', 'ACVR2A']
# Receptors: BMP5, OK: ['BMPR1A', 'ACVR2A']
# ----------
# Ligand: BMP5, OK: True
# Receptors: BMP5, OK: ['BMPR1A', None]
# Receptors: BMP5, OK: ['BMPR1A', 'ACVR2B']
# ----------
# Ligand: BMP5, OK: True
# Receptors: BMP5, OK: ['BMPR1A', 'BMPR2']
# Receptors: BMP5, OK: ['BMPR1A', 'BMPR2']
# ----------
# Ligand: BMP5, OK: True
# Receptors: BMP5, OK: [None, 'ACVR2A']
# Receptors: BMP5, OK: ['BMPR1B', 'ACVR2A']
# ----------
# Ligand: BMP5, OK: True
# Receptors: BMP5, OK: [None, None]
# Receptors: BMP5, OK: ['BMPR1B', 'ACVR2B']
# ----------
# Ligand: BMP5, OK: True
# Receptors: BMP5, OK: [None, 'BMPR2']
# Receptors: BMP5, OK: ['BMPR1B', 'BMPR2']
# ----------
# Ligand: BMP6, OK: True
# Receptors: BMP6, OK: ['ACVR1', 'ACVR2A']
# Receptors: BMP6, OK: ['ACVR1', 'ACVR2A']
# ----------
# Ligand: BMP6, OK: True
# Receptors: BMP6, OK: ['ACVR1', None]
# Receptors: BMP6, OK: ['ACVR1', 'ACVR2B']
# ----------
# Ligand: BMP6, OK: True
# Receptors: BMP6, OK: ['ACVR1', 'BMPR2']
# Receptors: BMP6, OK: ['ACVR1', 'BMPR2']
# ----------
# Ligand: BMP6, OK: True
# Receptors: BMP6, OK: ['BMPR1A', 'ACVR2A']
# Receptors: BMP6, OK: ['BMPR1A', 'ACVR2A']
# ----------
# Ligand: BMP6, OK: True
# Receptors: BMP6, OK: ['BMPR1A', None]
# Receptors: BMP6, OK: ['BMPR1A', 'ACVR2B']
# ----------
# Ligand: BMP6, OK: True
# Receptors: BMP6, OK: ['BMPR1A', 'BMPR2']
# Receptors: BMP6, OK: ['BMPR1A', 'BMPR2']
# ----------
# Ligand: BMP6, OK: True
# Receptors: BMP6, OK: [None, 'ACVR2A']
# Receptors: BMP6, OK: ['BMPR1B', 'ACVR2A']
# ----------
# Ligand: BMP6, OK: True
# Receptors: BMP6, OK: [None, None]
# Receptors: BMP6, OK: ['BMPR1B', 'ACVR2B']
# ----------
# Ligand: BMP6, OK: True
# Receptors: BMP6, OK: [None, 'BMPR2']
# Receptors: BMP6, OK: ['BMPR1B', 'BMPR2']
# ----------
# Ligand: BMP7, OK: True
# Receptors: BMP7, OK: ['ACVR1', 'ACVR2A']
# Receptors: BMP7, OK: ['ACVR1', 'ACVR2A']
# ----------
# Ligand: BMP7, OK: True
# Receptors: BMP7, OK: ['ACVR1', None]
# Receptors: BMP7, OK: ['ACVR1', 'ACVR2B']
# ----------
# Ligand: BMP7, OK: True
# Receptors: BMP7, OK: ['ACVR1', 'BMPR2']
# Receptors: BMP7, OK: ['ACVR1', 'BMPR2']
# ----------
# Ligand: BMP7, OK: True
# Receptors: BMP7, OK: ['BMPR1A', 'ACVR2A']
# Receptors: BMP7, OK: ['BMPR1A', 'ACVR2A']
# ----------
# Ligand: BMP7, OK: True
# Receptors: BMP7, OK: ['BMPR1A', None]
# Receptors: BMP7, OK: ['BMPR1A', 'ACVR2B']
# ----------
# Ligand: BMP7, OK: True
# Receptors: BMP7, OK: ['BMPR1A', 'BMPR2']
# Receptors: BMP7, OK: ['BMPR1A', 'BMPR2']
# ----------
# Ligand: BMP7, OK: True
# Receptors: BMP7, OK: [None, 'ACVR2A']
# Receptors: BMP7, OK: ['BMPR1B', 'ACVR2A']
# ----------
# Ligand: BMP7, OK: True
# Receptors: BMP7, OK: [None, None]
# Receptors: BMP7, OK: ['BMPR1B', 'ACVR2B']
# ----------
# Ligand: BMP7, OK: True
# Receptors: BMP7, OK: [None, 'BMPR2']
# Receptors: BMP7, OK: ['BMPR1B', 'BMPR2']
# ----------
# Ligand: BMP8A, OK: False
# Receptors: None, OK: ['ACVR1', 'ACVR2A']
# Receptors: BMP8A, OK: ['ACVR1', 'ACVR2A']
# ----------
# Ligand: BMP8A, OK: False
# Receptors: None, OK: ['ACVR1', None]
# Receptors: BMP8A, OK: ['ACVR1', 'ACVR2B']
# ----------
# Ligand: BMP8A, OK: False
# Receptors: None, OK: ['ACVR1', 'BMPR2']
# Receptors: BMP8A, OK: ['ACVR1', 'BMPR2']
# ----------
# Ligand: BMP8A, OK: False
# Receptors: None, OK: ['BMPR1A', 'ACVR2A']
# Receptors: BMP8A, OK: ['BMPR1A', 'ACVR2A']
# ----------
# Ligand: BMP8A, OK: False
# Receptors: None, OK: ['BMPR1A', None]
# Receptors: BMP8A, OK: ['BMPR1A', 'ACVR2B']
# ----------
# Ligand: BMP8A, OK: False
# Receptors: None, OK: ['BMPR1A', 'BMPR2']
# Receptors: BMP8A, OK: ['BMPR1A', 'BMPR2']
# ----------
# Ligand: BMP8A, OK: False
# Receptors: None, OK: [None, 'ACVR2A']
# Receptors: BMP8A, OK: ['BMPR1B', 'ACVR2A']
# ----------
# Ligand: BMP8A, OK: False
# Receptors: None, OK: [None, None]
# Receptors: BMP8A, OK: ['BMPR1B', 'ACVR2B']
# ----------
# Ligand: BMP8A, OK: False
# Receptors: None, OK: [None, 'BMPR2']
# Receptors: BMP8A, OK: ['BMPR1B', 'BMPR2']
# ----------
# Ligand: BMP8B, OK: False
# Receptors: None, OK: ['ACVR1', 'ACVR2A']
# Receptors: BMP8B, OK: ['ACVR1', 'ACVR2A']
# ----------
# Ligand: BMP8B, OK: False
# Receptors: None, OK: ['ACVR1', None]
# Receptors: BMP8B, OK: ['ACVR1', 'ACVR2B']
# ----------
# Ligand: BMP8B, OK: False
# Receptors: None, OK: ['ACVR1', 'BMPR2']
# Receptors: BMP8B, OK: ['ACVR1', 'BMPR2']
# ----------
# Ligand: BMP8B, OK: False
# Receptors: None, OK: ['BMPR1A', 'ACVR2A']
# Receptors: BMP8B, OK: ['BMPR1A', 'ACVR2A']
# ----------
# Ligand: BMP8B, OK: False
# Receptors: None, OK: ['BMPR1A', None]
# Receptors: BMP8B, OK: ['BMPR1A', 'ACVR2B']
# ----------
# Ligand: BMP8B, OK: False
# Receptors: None, OK: ['BMPR1A', 'BMPR2']
# Receptors: BMP8B, OK: ['BMPR1A', 'BMPR2']
# ----------
# Ligand: BMP8B, OK: False
# Receptors: None, OK: [None, 'ACVR2A']
# Receptors: BMP8B, OK: ['BMPR1B', 'ACVR2A']
# ----------
# Ligand: BMP8B, OK: False
# Receptors: None, OK: [None, None]
# Receptors: BMP8B, OK: ['BMPR1B', 'ACVR2B']
# ----------
# Ligand: BMP8B, OK: False
# Receptors: None, OK: [None, 'BMPR2']
# Receptors: BMP8B, OK: ['BMPR1B', 'BMPR2']
# ----------
# Ligand: BMP10, OK: False
# Receptors: None, OK: ['ACVRL1', 'BMPR2']
# Receptors: BMP10, OK: ['ACVRL1', 'BMPR2']
# ----------
# Ligand: BMP10, OK: False
# Receptors: None, OK: ['ACVRL1', 'ACVR2A']
# Receptors: BMP10, OK: ['ACVRL1', 'ACVR2A']
# ----------
# Ligand: GDF2, OK: False
# Receptors: None, OK: ['ACVRL1', 'BMPR2']
# Receptors: GDF2, OK: ['ACVRL1', 'BMPR2']
# ----------
# Ligand: GDF2, OK: False
# Receptors: None, OK: ['ACVRL1', 'ACVR2A']
# Receptors: GDF2, OK: ['ACVRL1', 'ACVR2A']
# ----------
# Ligand: GDF9, OK: True
# Receptors: GDF9, OK: ['ACVR1B', 'BMPR2']
# Receptors: GDF9, OK: ['ACVR1B', 'BMPR2']
# ----------
# Ligand: GDF10, OK: True
# Receptors: GDF10, OK: ['ACVR1B', 'ACVR2A']
# Receptors: GDF10, OK: ['ACVR1B', 'ACVR2A']
# ----------
# Ligand: GDF11, OK: False
# Receptors: None, OK: ['TGFBR1', 'ACVR2A']
# Receptors: GDF11, OK: ['TGFBR1', 'ACVR2A']
# ----------
# Ligand: GDF11, OK: False
# Receptors: None, OK: ['TGFBR1', None]
# Receptors: GDF11, OK: ['TGFBR1', 'ACVR2B']
# ----------
# Ligand: GDF11, OK: False
# Receptors: None, OK: ['ACVR1B', None]
# Receptors: GDF11, OK: ['ACVR1B', 'ACVR2B']
# ----------
# Ligand: GDF15, OK: True
# Receptors: GDF15, OK: ['TGFBR2']
# Receptors: GDF15, OK: ['TGFBR2']
# ----------
# Ligand: MSTN, OK: False
# Receptors: None, OK: ['TGFBR1', None]
# Receptors: MSTN, OK: ['TGFBR1', 'ACVR2B']
# ----------
# Ligand: MSTN, OK: False
# Receptors: None, OK: ['ACVR1B', None]
# Receptors: MSTN, OK: ['ACVR1B', 'ACVR2B']
# ----------

# %% [markdown]
# ### Functions

# %%
def get_interaction_status_mRNA(adata_rna, sample_id, distance_threshold, target_cell_type, cell_type_1, sender_genes, reciever_genes):
    """
    Determine whether a particular cell group is interacting with one or two other cell groups.

    Parameters
    ----------
    adata : AnnData
        Annotated data object with spatial transcriptomics or single-cell data.
    sample_id : str
        Identifier for the sample to analyze within `adata`.
    distance_threshold : float
        Distance in microns to define interaction.
    target_cell_type : str
        Cell type to check interactions for.
    cell_type_1 : str, optional
        First target cell type to assess interaction with (default: "Neutrophil").
    cell_type_2 : str, optional
        Second target cell type to assess interaction with (default: "NA").

    Returns
    -------
    dict
        Contains:
        - "Interaction Matrix": pandas.DataFrame with interaction booleans and status labels.
    """
    import pandas as pd

    # Get distance matrix for cell_type_1
    results_1 = nearest_cells_of_particular_type_mRNA(adata_rna, sample_id, target_cell_type, cell_type_1,sender_genes, reciever_genes)["Distance Matrix"]
    threshold = distance_threshold

    output = pd.DataFrame(index=results_1.index)
    output[f'{cell_type_1} Interacting'] = results_1['Minimum Distance'] <= threshold

    # Classify into two categories
    def classify(row):
        if row[f'{cell_type_1} Interacting']:
            return 'Interacting'
        else:
            return 'Not Interacting'

    output['Interaction_Status'] = output.apply(classify, axis=1)

    return {
        "Interaction Matrix": output
    }

def nearest_cells_of_particular_type_mRNA(adata_rna,sample_ID,orgin_cell_types,cell_distance_types,sender_genes,reciever_genes):
    """
    Calculates distance matrix between PMNs and target cells of a particular type,
    along with summary statistics.

    Parameters:
    -----------
    adata : AnnData
        Annotated data object containing spatial information for cells.
    sample_ID : str
        Identifier for the specific sample to analyze.
    orgin_cell_type : str
        The string name of the orgin cell specified. This will mostly commonly be neutrophils
    cell_distance_type : str
        Cell type to use as the target for distance calculations (e.g., "CD4+T_cells").

    Returns:
    --------
    dict
        A dictionary containing:
        - 'Distance Matrix' (pd.DataFrame): Matrix of distances between orgin and target cells,
          including additional columns for 'Minimum Distance' and 'Average Distance' per orging cell.
        - 'Average Distance' (float): Overall average distance across the entire matrix.
        - 'Average Mininum Distance' (float): Average of each orgin cell's minimum distance to target cells.
    """
    import pandas as pd

    # Creates lists of cell types for PMN and the target comparison
    orgin_cell_type_list = gene_expression_cell_list(adata_rna,sample_ID,sender_genes,orgin_cell_types)
    target_cell_list = gene_expression_cell_list(adata_rna,sample_ID,reciever_genes,cell_distance_types)
    
    # Initialize results storage: one column for this cell type
    distance_matrix = pd.DataFrame(index=orgin_cell_type_list, columns=target_cell_list)
    
    for pmn in orgin_cell_type_list:
        for target_cell in target_cell_list:
            distance_matrix.loc[pmn,target_cell]=find_distance_mRNA(adata_rna,pmn, target_cell)["Distance um"]
    
    # Ensure numeric types
    distance_matrix = distance_matrix.apply(pd.to_numeric, errors='coerce')
    
    # Calculate overall average distance across entire matrix
    overall_avg_distance = distance_matrix.mean().mean()

    # Calculate average mininum distance
    average_min_distance = distance_matrix.min(axis=1).mean()
            
    # Add columns first (unrounded)
    distance_matrix['Minimum Distance'] = distance_matrix.min(axis=1).round(2)
    distance_matrix['Average Distance'] = distance_matrix.mean(axis=1).round(2)
    
    return{
        "Distance Matrix":distance_matrix,
        "Average Distance":overall_avg_distance,
        "Average Mininum Distance": average_min_distance
    }
    
def gene_expression_cell_list(adata_rna, name_string, gene_targets, cell_filter_list):
    """
    Retrieve the list of cells that express any of the given genes and match cell type criteria.
    
    Parameters:
    - adata_rna: AnnData object
    - name_string: The name of the punch without the cell number. Ex "c_1_1"
    - gene_targets: List of genes being targeted in the expression file
    - cell_filter_list: List of cell types (annot_cluster_2) to include in results
    
    Returns:
    - List of cell IDs that meet the gene expression and cell type criteria
    """

    # Ensure gene_targets is a list
    if isinstance(gene_targets, str):
        gene_targets = [gene_targets]

    # Subset by tma_fov_id
    adata_sub = adata_rna[adata_rna.obs["tma_fov_id"] == name_string].copy()

    # Filter by cell type
    if cell_filter_list:
        adata_sub = adata_sub[adata_sub.obs["annot_cluster2"].isin(cell_filter_list)].copy()

    # Ensure all genes exist
    missing_genes = [g for g in gene_targets if g not in adata_sub.var_names]
    if missing_genes:
        raise ValueError(f"Genes not found: {missing_genes}")

    # Get expression values for all genes
    expr_values = adata_sub[:, gene_targets].X

    # Convert sparse to dense if needed
    if hasattr(expr_values, "toarray"):
        expr_values = expr_values.toarray()

    # Keep cells where ANY gene has expression > 0
    mask = (expr_values > 0).any(axis=1)

    # Return matching cell IDs
    return adata_sub.obs.index[mask].tolist()

def get_xy_coords_mRNA(adata_rna,cell_ID):
    """
    Retrieve the XY pixel coordinates for a given cell.
    Parameters:
    ----------
    adata : AnnData
    cell_ID : str
        Unique identifier for the cell.
    Returns:
    -------
    dict
        Dictionary containing:
        - "X": X-coordinate in pixels (int)
        - "Y": Y-coordinate in pixels (int)
    """
    x_coord=adata_rna.obs.loc[cell_ID, "x_pixel"]
    y_coord=adata_rna.obs.loc[cell_ID, "y_pixel"]
    
    return{
        "X":x_coord,
        "Y":y_coord
    }
    
def find_distance_mRNA(adata_rna,cell_ID_1,cell_ID_2,unit_conversion=0.168):
    """
    Calculate the Euclidean distance between two cells based on their XY coordinates.
    Parameters:
    ----------
    cell_ID_1 : str
        Unique identifier for the first cell.
    cell_ID_2 : str
        Unique identifier for the second cell.
    unit_conversion : float, optional
        Conversion factor from pixels to microns. Default is 0.168 µm/px.

    Returns:
    -------
    dict
        Dictionary containing:
        - "Distance px": Distance between cells in pixels (float)
        - "Distance um": Distance between cells in microns (float)
    """
    from math import sqrt
    # Get Cell Locations
    cell_1_xy=get_xy_coords_mRNA(adata_rna,cell_ID_1)
    cell_2_xy=get_xy_coords_mRNA(adata_rna,cell_ID_2)

    # Distance Function
    Distance_px = sqrt((cell_2_xy["X"] - cell_1_xy["X"])**2 + (cell_2_xy["Y"] - cell_1_xy["Y"])**2)

    # Convert pixel distance to micron
    Distance_um = Distance_px*unit_conversion

    return{
            "Distance px":Distance_px,
            "Distance um": Distance_um
        }

# %% [markdown]
# ### Run Setup

# %%
myloid_cells=["Macrophages", "Monocytes", "DCs"]
All_cells=['Bcells','DCs','Endothelials','Fibroblast_VEGFA_inflammatorylike_CAFs','Fibroblast_apCAFs','Fibroblast_myCAFs','Macrophages','Monocytes','Plasma','TcellsCD8+','Tcells_CD4+','Tregs','Tumors_HIF1A+','Tumors_KRT17+','Tumors_KRT19+','Tumors_Others']
all_cell_minus_tumor=['Bcells','DCs','Endothelials','Fibroblast_VEGFA_inflammatorylike_CAFs','Fibroblast_apCAFs','Fibroblast_myCAFs','Macrophages','Monocytes','Plasma','TcellsCD8+','Tcells_CD4+','Tregs']
myloid_cells=all_cell_minus_tumor
t_cells=["TcellsCD8+","Tcells_CD4+","Tregs"]

# SENDER and RECIEVER GENES
sender_genes=["CXCL9","CXCL10"]
reciever_genes=["CXCR3"]

# SENDER AND RECIEVER CELLS
sender_cells=All_cells
receiver_cells=All_cells

# %% [markdown]
# ### Main Execution

# %%
data=[]

TMA_CORE=["A","B","C"]
for i in range(1,26):
    for j in range(1,2):  # This loop only runs once with j=1
        rna_sample_id = f"TMA_{TMA_CORE[j-1]}_FOV{i}"
        display(rna_sample_id)
        subset=adata_rna[adata_rna.obs["tma_fov_id"].fillna("") == rna_sample_id].copy()
        patient_id = subset.obs["PatientID"].unique()[0]
        response_status = subset.obs["Response"].unique()[0]
        
        results=get_interaction_status_mRNA(subset,rna_sample_id,15,sender_cells,receiver_cells,sender_genes,reciever_genes)
        
        output=results["Interaction Matrix"]
        
        # Count interactions
        counts = output["Interaction_Status"].value_counts()
        
        # Extract numbers
        n_interacting = counts.get("Interacting", 0)
        n_not_interacting = counts.get("Not Interacting", 0)
        
        # Compute percent interacting
        percent_interacting = (n_interacting / (n_interacting + n_not_interacting)) * 100 if (n_interacting + n_not_interacting) > 0 else 0
        
        summary_row = pd.DataFrame([{
            "Interacting": n_interacting,
            "Not Interacting": n_not_interacting,
            "Percent Interacting": percent_interacting,
            "Response": response_status,
            "Patient Id": patient_id
        }], index=[rna_sample_id])

        data.append(summary_row)

        # -----------------------------
        # Mean & Median Statistics
        # -----------------------------
        
        # Split responders vs non-responders
        responders = final_df[final_df["Response"] == "R"]
        nonresponders = final_df[final_df["Response"] == "NR"]
        
        R_mean=responders["Percent Interacting"].mean()
        R_median=responders["Percent Interacting"].median()
        NR_mean=nonresponders["Percent Interacting"].mean()
        NR_median=nonresponders["Percent Interacting"].median()

final_df = pd.concat(data)
display(final_df)
# Out:
# 'TMA_A_FOV1'
# 'TMA_A_FOV2'
# 'TMA_A_FOV3'
# 'TMA_A_FOV4'
# 'TMA_A_FOV5'
# 'TMA_A_FOV6'
# 'TMA_A_FOV7'
# 'TMA_A_FOV8'
# 'TMA_A_FOV9'
# 'TMA_A_FOV10'
# 'TMA_A_FOV11'
# 'TMA_A_FOV12'
# 'TMA_A_FOV13'
# 'TMA_A_FOV14'
# 'TMA_A_FOV15'
# 'TMA_A_FOV16'
# 'TMA_A_FOV17'
# 'TMA_A_FOV18'
# 'TMA_A_FOV19'
# 'TMA_A_FOV20'
# 'TMA_A_FOV21'
# 'TMA_A_FOV22'
# 'TMA_A_FOV23'
# 'TMA_A_FOV24'
# 'TMA_A_FOV25'
#              Interacting  Not Interacting  Percent Interacting Response  \
# TMA_A_FOV1           129              181            41.612903        R
# TMA_A_FOV2           232              866            21.129326        R
# TMA_A_FOV3           386             1094            26.081081        R
# TMA_A_FOV4            69              460            13.043478        R
# TMA_A_FOV5            59              584             9.175739        R
# TMA_A_FOV6           146              668            17.936118       NR
# TMA_A_FOV7            45              277            13.975155       NR
# TMA_A_FOV8           251              505            33.201058       NR
# TMA_A_FOV9            48              669             6.694561       NR
# TMA_A_FOV10           23              235             8.914729        R
# TMA_A_FOV11           92              581            13.670134        R
# TMA_A_FOV12           61              459            11.730769        R
# TMA_A_FOV13           76              375            16.851441       NR
# TMA_A_FOV14            9              124             6.766917       NR
# TMA_A_FOV15           16              197             7.511737       NR
# TMA_A_FOV16          248              568            30.392157       NR
# TMA_A_FOV17           34              290            10.493827       NR
# TMA_A_FOV18          191             1450            11.639244        R
# TMA_A_FOV19          166             1079            13.333333        R
# TMA_A_FOV20           38              171            18.181818        R
# TMA_A_FOV21          316             1207            20.748523       NR
# TMA_A_FOV22          197              477            29.228487        R
# TMA_A_FOV23           17              172             8.994709       NR
# TMA_A_FOV24           52              449            10.379242       NR
# TMA_A_FOV25          128              303            29.698376        R
#
#             Patient Id
# TMA_A_FOV1           W
# TMA_A_FOV2           W
# TMA_A_FOV3           X
# TMA_A_FOV4           X
# TMA_A_FOV5           X
# TMA_A_FOV6           T
# TMA_A_FOV7           P
# TMA_A_FOV8           R
# TMA_A_FOV9           R
# TMA_A_FOV10          S
# TMA_A_FOV11          M
# TMA_A_FOV12          M
# TMA_A_FOV13          N
# TMA_A_FOV14          E
# TMA_A_FOV15          E
# TMA_A_FOV16          F
# TMA_A_FOV17          F
# TMA_A_FOV18          A
# TMA_A_FOV19          A
# TMA_A_FOV20          B
# TMA_A_FOV21          R
# TMA_A_FOV22          M
# TMA_A_FOV23          J
# TMA_A_FOV24          K
# TMA_A_FOV25          B

# %%
# -----------------------------
# Mean & Median Statistics
# -----------------------------

# Split responders vs non-responders
responders = final_df[final_df["Response"] == "R"]
nonresponders = final_df[final_df["Response"] == "NR"]

R_mean=responders["Percent Interacting"].mean()
R_median=responders["Percent Interacting"].median()
NR_mean=nonresponders["Percent Interacting"].mean()
NR_median=nonresponders["Percent Interacting"].median()
# Out:
# 19.033801336742403
# 13.670133729569093
# 15.328787074819052
# 12.234491219998464

# %% [markdown]
# ### Multi Gene Main Execution

# %%
TMA_CORE=["A","B","C"]

for z in range(1,10):
    ligand = lr_array[z, 0]
    receptor = lr_array[z, 1]

    # Convert receptor string to list
    receptor_list = receptor.split("_")

    # Check if they exist in expr.columns
    ligand_ok, receptors_ok, ligand_corrected, corrected_receptors = check_expression(ligand, receptor_list, expr)

    print(f"Ligand: {ligand}, OK: {ligand_ok}")
    print(f"Receptors: {receptor_list}, OK: {receptors_ok}")
    print("----------")

    if ligand_ok==False or receptors_ok==False:
        display(f"Skipping Ligand: {ligand} and Receptor List: {receptor_list} due to some not existing in the columns")
        continue

    sender_genes=ligand_corrected
    reciever_genes=corrected_receptors
    
    TMA_CORE=["A","B","C"]
    data=[]
    for i in range(1,15):
        for j in range(1,2):  # This loop only runs once with j=1
            rna_sample_id = f"TMA_{TMA_CORE[j-1]}_FOV{i}"
            display(rna_sample_id)
            subset=adata_rna[adata_rna.obs["tma_fov_id"].fillna("") == rna_sample_id].copy()
            patient_id = subset.obs["PatientID"].unique()[0]
            response_status = subset.obs["Response"].unique()[0]
            
            results=get_interaction_status_mRNA(subset,rna_sample_id,15,myloid_cells,t_cells,sender_genes,reciever_genes)
            
            output=results["Interaction Matrix"]
            
            # Count interactions
            counts = output["Interaction_Status"].value_counts()
            
            # Extract numbers
            n_interacting = counts.get("Interacting", 0)
            n_not_interacting = counts.get("Not Interacting", 0)
            
            # Compute percent interacting
            percent_interacting = (n_interacting / (n_interacting + n_not_interacting)) * 100 if (n_interacting + n_not_interacting) > 0 else 0
            
            summary_row = pd.DataFrame([{
                "Interacting": n_interacting,
                "Not Interacting": n_not_interacting,
                "Percent Interacting": percent_interacting,
                "Response": response_status,
                "Patient Id": patient_id
            }], index=[rna_sample_id])
    
            data.append(summary_row)
    
    # -----------------------------
    # Mean & Median Statistics
    # -----------------------------
            
    # Split responders vs non-responders
    final_df = pd.concat(data)
    responders = final_df[final_df["Response"] == "R"]
    nonresponders = final_df[final_df["Response"] == "NR"]
            
    R_mean=responders["Percent Interacting"].mean()
    R_median=responders["Percent Interacting"].median()
    NR_mean=nonresponders["Percent Interacting"].mean()
    NR_median=nonresponders["Percent Interacting"].median()

    # ------------------------------
    # Create Output Matrix
    # ------------------------------
    # The output matrix should have the following columns: (1) ligand (2) receptor (3) median responder (4) median nonresponder (5) difference 
    

    display(final_df)
    display(R_mean)
    display(R_median)
    display(NR_mean)
    display(NR_median)
# Out:
# Ligand: TGFB2, OK: True
# Receptors: ['TGFbR1', 'R2'], OK: False
# ----------
# "Skipping Ligand: TGFB2 and Receptor List: ['TGFbR1', 'R2'] due to some not existing in the columns"
# Ligand: TGFB3, OK: True
# Receptors: ['TGFbR1', 'R2'], OK: False
# ----------
# "Skipping Ligand: TGFB3 and Receptor List: ['TGFbR1', 'R2'] due to some not existing in the columns"
# Ligand: TGFB1, OK: True
# Receptors: ['ACVR1B', 'TGFbR2'], OK: True
# ----------
# 'TMA_A_FOV1'
# 'TMA_A_FOV2'
# 'TMA_A_FOV3'
# 'TMA_A_FOV4'
# 'TMA_A_FOV5'
# 'TMA_A_FOV6'
# 'TMA_A_FOV7'
# 'TMA_A_FOV8'
# 'TMA_A_FOV9'
# 'TMA_A_FOV10'
# 'TMA_A_FOV11'
# 'TMA_A_FOV12'
# 'TMA_A_FOV13'
# 'TMA_A_FOV14'
# 18.85137754726657
# 19.43943153620573
# 20.318513617197365
# 18.299595141700408
# Ligand: TGFB1, OK: True
# Receptors: ['ACVR1C', 'TGFbR2'], OK: False
# ----------
# "Skipping Ligand: TGFB1 and Receptor List: ['ACVR1C', 'TGFbR2'] due to some not existing in the columns"
# Ligand: TGFB2, OK: True
# Receptors: ['ACVR1B', 'TGFbR2'], OK: True
# ----------
# 'TMA_A_FOV1'
# 'TMA_A_FOV2'
# 'TMA_A_FOV3'
# 'TMA_A_FOV4'
# 'TMA_A_FOV5'
# 'TMA_A_FOV6'
# 'TMA_A_FOV7'
# 'TMA_A_FOV8'
# 'TMA_A_FOV9'
# 'TMA_A_FOV10'
# 'TMA_A_FOV11'
# 'TMA_A_FOV12'
# 'TMA_A_FOV13'
# 'TMA_A_FOV14'
# 16.089521734692386
# 15.908054711246201
# 20.680983412798604
# 20.410051202616067
# Ligand: TGFB2, OK: True
# Receptors: ['ACVR1C', 'TGFbR2'], OK: False
# ----------
# "Skipping Ligand: TGFB2 and Receptor List: ['ACVR1C', 'TGFbR2'] due to some not existing in the columns"
# Ligand: TGFB3, OK: True
# Receptors: ['ACVR1B', 'TGFbR2'], OK: True
# ----------
# 'TMA_A_FOV1'
# 'TMA_A_FOV2'
# 'TMA_A_FOV3'
# 'TMA_A_FOV4'
# 'TMA_A_FOV5'
# 'TMA_A_FOV6'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28084\3019560051.py in ?()
#      30             subset=adata_rna[adata_rna.obs["tma_fov_id"].fillna("") == rna_sample_id].copy()
#      31             patient_id = subset.obs["PatientID"].unique()[0]
#      32             response_status = subset.obs["Response"].unique()[0]
#      33
# ---> 34             results=get_interaction_status_mRNA(subset,rna_sample_id,3,sender_cells,receiver_cells,sender_genes,reciever_genes)
#      35
#      36             output=results["Interaction Matrix"]
#      37
#
# ~\AppData\Local\Temp\ipykernel_28084\258519584.py in ?(adata_rna, sample_id, distance_threshold, target_cell_type, cell_type_1, sender_genes, reciever_genes)
#      25     """
#      26     import pandas as pd
#      27
#      28     # Get distance matrix for cell_type_1
# ---> 29     results_1 = nearest_cells_of_particular_type_mRNA(adata_rna, sample_id, target_cell_type, cell_type_1,sender_genes, reciever_genes)["Distance Matrix"]
#      30     threshold = distance_threshold
#      31
#      32     output = pd.DataFrame(index=results_1.index)
#
# ~\AppData\Local\Temp\ipykernel_28084\258519584.py in ?(adata_rna, sample_ID, orgin_cell_types, cell_distance_types, sender_genes, reciever_genes)
#      98     distance_matrix = pd.DataFrame(index=orgin_cell_type_list, columns=target_cell_list)
#      99
#     100     for pmn in orgin_cell_type_list:
#     101         for target_cell in target_cell_list:
# --> 102             distance_matrix.loc[pmn,target_cell]=find_distance_mRNA(adata_rna,pmn, target_cell)["Distance um"]
#     103
#     104     # Ensure numeric types
#     105     distance_matrix = distance_matrix.apply(pd.to_numeric, errors='coerce')
#
# ~\anaconda3\Lib\site-packages\pandas\core\indexing.py in ?(self, key, value)
#     907         indexer = self._get_setitem_indexer(key)
#     908         self._has_valid_setitem_indexer(key)
#     909
#     910         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911         iloc._setitem_with_indexer(indexer, value, self.name)
#
# ~\anaconda3\Lib\site-packages\pandas\core\indexing.py in ?(self, indexer, value, name)
#    1940         if take_split_path:
#    1941             # We have to operate column-wise
#    1942             self._setitem_with_indexer_split_path(indexer, value, name)
#    1943         else:
# -> 1944             self._setitem_single_block(indexer, value, name)
#
# ~\anaconda3\Lib\site-packages\pandas\core\indexing.py in ?(self, indexer, value, name)
#    2215         self.obj._check_is_chained_assignment_possible()
#    2216
#    2217         # actually do the set
#    2218         self.obj._mgr = self.obj._mgr.setitem(indexer=indexer, value=value)
# -> 2219         self.obj._maybe_update_cacher(clear=True, inplace=True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, clear, verify_is_copy, inplace)
# -> 3995     def _maybe_update_cacher(
#    3996         self,
#    3997         clear: bool_t = False,
#    3998         verify_is_copy: bool_t = True,
#
# KeyboardInterrupt:

# %%
TMA_CORE = ["A","B","C"]
output_matrix = []  # Will store all ligand–receptor stats

for z in range(1, 10):
    ligand = lr_array[z, 0]
    receptor = lr_array[z, 1]

    # Convert receptor string to list
    receptor_list = receptor.split("_")

    # Check if they exist in expr.columns
    ligand_ok, receptors_ok, ligand_corrected, corrected_receptors = check_expression(ligand, receptor_list, expr)

    print(f"Ligand: {ligand}, OK: {ligand_ok}")
    print(f"Receptors: {receptor_list}, OK: {receptors_ok}")
    print("----------")

    if not ligand_ok or not receptors_ok:
        display(f"Skipping Ligand: {ligand} and Receptor List: {receptor_list} due to missing in expr.columns")
        continue

    sender_genes = ligand_corrected
    reciever_genes = corrected_receptors

    data = []
    for i in range(1, 15):
        for j in range(1, 2):  # Only runs once with j=1
            rna_sample_id = f"TMA_{TMA_CORE[j-1]}_FOV{i}"
            display(rna_sample_id)

            subset = adata_rna[adata_rna.obs["tma_fov_id"].fillna("") == rna_sample_id].copy()
            patient_id = subset.obs["PatientID"].unique()[0]
            response_status = subset.obs["Response"].unique()[0]

            results = get_interaction_status_mRNA(
                subset, rna_sample_id, 15,
                myloid_cells, t_cells, sender_genes, reciever_genes
            )

            output = results["Interaction Matrix"]

            # Count interactions
            counts = output["Interaction_Status"].value_counts()
            n_interacting = counts.get("Interacting", 0)
            n_not_interacting = counts.get("Not Interacting", 0)
            percent_interacting = (
                n_interacting / (n_interacting + n_not_interacting) * 100
                if (n_interacting + n_not_interacting) > 0 else 0
            )

            summary_row = pd.DataFrame([{
                "Interacting": n_interacting,
                "Not Interacting": n_not_interacting,
                "Percent Interacting": percent_interacting,
                "Response": response_status,
                "Patient Id": patient_id
            }], index=[rna_sample_id])

            data.append(summary_row)

    # Combine all sample rows
    final_df = pd.concat(data)

    # Split responders vs non-responders
    responders = final_df[final_df["Response"] == "R"]
    nonresponders = final_df[final_df["Response"] == "NR"]

    R_median = responders["Percent Interacting"].median()
    NR_median = nonresponders["Percent Interacting"].median()

    # ------------------------------
    # Build labeled output matrix
    # ------------------------------
    output_matrix.append({
        "ligand": sender_genes,
        "receptor": "_".join(reciever_genes),
        "median_responder": R_median,
        "median_nonresponder": NR_median,
        "difference": R_median - NR_median
    })

    # Optional: display per ligand
    display(final_df)
    display(f"Responder median: {R_median}")
    display(f"Non-responder median: {NR_median}")

# Convert final output matrix to DataFrame
output_df = pd.DataFrame(output_matrix)
display(output_df)
# Out:
# Ligand: TGFB2, OK: True
# Receptors: ['TGFbR1', 'R2'], OK: False
# ----------
# "Skipping Ligand: TGFB2 and Receptor List: ['TGFbR1', 'R2'] due to missing in expr.columns"
# Ligand: TGFB3, OK: True
# Receptors: ['TGFbR1', 'R2'], OK: False
# ----------
# "Skipping Ligand: TGFB3 and Receptor List: ['TGFbR1', 'R2'] due to missing in expr.columns"
# Ligand: TGFB1, OK: True
# Receptors: ['ACVR1B', 'TGFbR2'], OK: True
# ----------
# 'TMA_A_FOV1'
# 'TMA_A_FOV2'
# 'TMA_A_FOV3'
# 'TMA_A_FOV4'
# 'TMA_A_FOV5'
# 'TMA_A_FOV6'
# 'TMA_A_FOV7'
# 'TMA_A_FOV8'
# 'TMA_A_FOV9'
# 'TMA_A_FOV10'
# 'TMA_A_FOV11'
# 'TMA_A_FOV12'
# 'TMA_A_FOV13'
# 'TMA_A_FOV14'
#              Interacting  Not Interacting  Percent Interacting Response  \
# TMA_A_FOV1           122              758            13.863636        R
# TMA_A_FOV2            21              341             5.801105        R
# TMA_A_FOV3            35              388             8.274232        R
# TMA_A_FOV4             3              179             1.648352        R
# TMA_A_FOV5             3              202             1.463415        R
# TMA_A_FOV6            15              500             2.912621       NR
# TMA_A_FOV7            11              348             3.064067       NR
# TMA_A_FOV8           138              370            27.165354       NR
# TMA_A_FOV9             6              223             2.620087       NR
# TMA_A_FOV10            0              108             0.000000        R
# TMA_A_FOV11           14              327             4.105572        R
# TMA_A_FOV12           28              465             5.679513        R
# TMA_A_FOV13            6              241             2.429150       NR
# TMA_A_FOV14            1              149             0.666667       NR
#
#             Patient Id
# TMA_A_FOV1           W
# TMA_A_FOV2           W
# TMA_A_FOV3           X
# TMA_A_FOV4           X
# TMA_A_FOV5           X
# TMA_A_FOV6           T
# TMA_A_FOV7           P
# TMA_A_FOV8           R
# TMA_A_FOV9           R
# TMA_A_FOV10          S
# TMA_A_FOV11          M
# TMA_A_FOV12          M
# TMA_A_FOV13          N
# TMA_A_FOV14          E
# 'Responder median: 4.892542516045754'
# 'Non-responder median: 2.7663543477339214'
# Ligand: TGFB1, OK: True
# Receptors: ['ACVR1C', 'TGFbR2'], OK: False
# ----------
# "Skipping Ligand: TGFB1 and Receptor List: ['ACVR1C', 'TGFbR2'] due to missing in expr.columns"
# Ligand: TGFB2, OK: True
# Receptors: ['ACVR1B', 'TGFbR2'], OK: True
# ----------
# 'TMA_A_FOV1'
# 'TMA_A_FOV2'
# 'TMA_A_FOV3'
# 'TMA_A_FOV4'
# 'TMA_A_FOV5'
# 'TMA_A_FOV6'
# 'TMA_A_FOV7'
# 'TMA_A_FOV8'
# 'TMA_A_FOV9'
# 'TMA_A_FOV10'
# 'TMA_A_FOV11'
# 'TMA_A_FOV12'
# 'TMA_A_FOV13'
# 'TMA_A_FOV14'
#              Interacting  Not Interacting  Percent Interacting Response  \
# TMA_A_FOV1            27              186            12.676056        R
# TMA_A_FOV2            23              306             6.990881        R
# TMA_A_FOV3            26              202            11.403509        R
# TMA_A_FOV4             1              167             0.595238        R
# TMA_A_FOV5             3               83             3.488372        R
# TMA_A_FOV6             4              250             1.574803       NR
# TMA_A_FOV7             2               87             2.247191       NR
# TMA_A_FOV8            26              157            14.207650       NR
# TMA_A_FOV9             2               58             3.333333       NR
# TMA_A_FOV10            4              216             1.818182        R
# TMA_A_FOV11            6              229             2.553191        R
# TMA_A_FOV12           14              295             4.530744        R
# TMA_A_FOV13            0               94             0.000000       NR
# TMA_A_FOV14            1               79             1.250000       NR
#
#             Patient Id
# TMA_A_FOV1           W
# TMA_A_FOV2           W
# TMA_A_FOV3           X
# TMA_A_FOV4           X
# TMA_A_FOV5           X
# TMA_A_FOV6           T
# TMA_A_FOV7           P
# TMA_A_FOV8           R
# TMA_A_FOV9           R
# TMA_A_FOV10          S
# TMA_A_FOV11          M
# TMA_A_FOV12          M
# TMA_A_FOV13          N
# TMA_A_FOV14          E
# 'Responder median: 4.009558214796417'
# 'Non-responder median: 1.9109970804211271'
# Ligand: TGFB2, OK: True
# Receptors: ['ACVR1C', 'TGFbR2'], OK: False
# ----------
# "Skipping Ligand: TGFB2 and Receptor List: ['ACVR1C', 'TGFbR2'] due to missing in expr.columns"
# Ligand: TGFB3, OK: True
# Receptors: ['ACVR1B', 'TGFbR2'], OK: True
# ----------
# 'TMA_A_FOV1'
# 'TMA_A_FOV2'
# 'TMA_A_FOV3'
# 'TMA_A_FOV4'
# 'TMA_A_FOV5'
# 'TMA_A_FOV6'
# 'TMA_A_FOV7'
# 'TMA_A_FOV8'
# 'TMA_A_FOV9'
# 'TMA_A_FOV10'
# 'TMA_A_FOV11'
# 'TMA_A_FOV12'
# 'TMA_A_FOV13'
# 'TMA_A_FOV14'
#              Interacting  Not Interacting  Percent Interacting Response  \
# TMA_A_FOV1            40              339            10.554090        R
# TMA_A_FOV2            71              659             9.726027        R
# TMA_A_FOV3            40              368             9.803922        R
# TMA_A_FOV4             3              213             1.388889        R
# TMA_A_FOV5             6              183             3.174603        R
# TMA_A_FOV6             6              345             1.709402       NR
# TMA_A_FOV7             6              119             4.800000       NR
# TMA_A_FOV8            75              247            23.291925       NR
# TMA_A_FOV9             4               62             6.060606       NR
# TMA_A_FOV10            0              131             0.000000        R
# TMA_A_FOV11           31              742             4.010349        R
# TMA_A_FOV12           29              458             5.954825        R
# TMA_A_FOV13           12              232             4.918033       NR
# TMA_A_FOV14            2              129             1.526718       NR
#
#             Patient Id
# TMA_A_FOV1           W
# TMA_A_FOV2           W
# TMA_A_FOV3           X
# TMA_A_FOV4           X
# TMA_A_FOV5           X
# TMA_A_FOV6           T
# TMA_A_FOV7           P
# TMA_A_FOV8           R
# TMA_A_FOV9           R
# TMA_A_FOV10          S
# TMA_A_FOV11          M
# TMA_A_FOV12          M
# TMA_A_FOV13          N
# TMA_A_FOV14          E
# 'Responder median: 4.982587375249368'
# 'Non-responder median: 4.859016393442623'
# Ligand: TGFB3, OK: True
# Receptors: ['ACVR1C', 'TGFbR2'], OK: False
# ----------
# "Skipping Ligand: TGFB3 and Receptor List: ['ACVR1C', 'TGFbR2'] due to missing in expr.columns"
# Ligand: TGFB1, OK: True
# Receptors: ['ACVR1', 'TGFbR'], OK: False
# ----------
# "Skipping Ligand: TGFB1 and Receptor List: ['ACVR1', 'TGFbR'] due to missing in expr.columns"
#   ligand       receptor  median_responder  median_nonresponder  difference
# 0  TGFB1  ACVR1B_TGFBR2          4.892543             2.766354    2.126188
# 1  TGFB2  ACVR1B_TGFBR2          4.009558             1.910997    2.098561
# 2  TGFB3  ACVR1B_TGFBR2          4.982587             4.859016    0.123571
